# %% [markdown]
# ### Вместо точек -- запятые!

# %%
#Locale settings
import locale
# Set to German locale to get comma decimal separater
locale.setlocale(locale.LC_NUMERIC, "deu_DEU")

import numpy as np
import matplotlib.pyplot as plt
plt.rcdefaults()

# Tell matplotlib to use the locale we set above
plt.rcParams['axes.formatter.use_locale'] = True

# %% [markdown]
# ### Запуск QtLab

# %%
# %matplotlib qt
from qsweepy import *
from qsweepy.ponyfiles import *
from qsweepy.instruments import *
from qsweepy.save_pkl import save_pkl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import interactive
interactive(True)
from importlib import reload

sample_name='Fluxonium_1907_063_2'

# %%
#Параметры кубитов.all keys should be str
qubits = {
          '1': {'r':{
                    'Fr': 4.95406e9, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 4.952e9,#6.575e9,
                    'Fr_max': 4.956e9,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':6,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '2': {'r':{
                    'Fr': 6.3208e9,#7.4095e9,#7.41e9, #7.413e9,# first sample # second sample 7.8816e9,#'Fr': 6.7335e9,
                    'Fr_min': 6.3108e9,#7.395e9,#6.72e9,
                    'Fr_max': 6.3308e9,#7.415e9,#down  8.32e9,#8.84e9,##6.788e9,#6.884e9,#6.92e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                    {'F01_min':3.788e9},#5.8e9#5.010e9 - up},#{'F01_min':5.519e9},#5.52025
                    'P':
                     {
                     'nndac_coil_id':8,#2,
                     'awg_tek_coil_channel':4,
                     'coil_device_channel':4,
                     'P':None, 
                     }
                }},
          '3': {'r':{
                    'Fr': 6.6814e9, # first sample # second sample 7.373e9,# second sample 7.376e9,#6.8791e9,
                    'Fr_min': 6.6704e9,#6.734e9,#6.879e9,#6.82e9,
                    'Fr_max': 6.6904e9,# down 6.850e9,#7.304e9, ##6.76e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                    {'F01_min': 4.83644e9 }, #4.1923e9# 4.17799e9 #4.467e9#4.464e9#4.203e9},#4.675e9},#4.484e9 -up},#{'F01_min':5.45525e9},#5.45678
                    'P':
                     {
                    'nndac_coil_id':10,#4,
                    'awg_tek_coil_channel':3,
                    'coil_device_channel':3,
                     'P':None, 
                     }
                }},
          '4': {'r':{
                    'Fr': 7.0171e9, # first sample # second sample 7.373e9,# second sample 7.376e9,#6.8791e9,
                    'Fr_min': 7.0151e9,#6.734e9,#6.879e9,#6.82e9,
                    'Fr_max': 7.0191e9,# down 6.850e9,#7.304e9, ##6.76e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                    {'F01_min': 4.83644e9 }, #4.1923e9# 4.17799e9 #4.467e9#4.464e9#4.203e9},#4.675e9},#4.484e9 -up},#{'F01_min':5.45525e9},#5.45678
                    'P':
                     {
                    'nndac_coil_id':10,#4,
                    'awg_tek_coil_channel':3,
                    'coil_device_channel':3,
                     'P':None, 
                     }
                }},
          '5': {'r':{
                    'Fr': 7.25381e9, # first sample # second sample 7.373e9,# second sample 7.376e9,#6.8791e9,
                    'Fr_min': 7.25175e9,#6.734e9,#6.879e9,#6.82e9,
                    'Fr_max': 7.25575e9,# down 6.850e9,#7.304e9, ##6.76e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                    {'F01_min': 4.83644e9 }, #4.1923e9# 4.17799e9 #4.467e9#4.464e9#4.203e9},#4.675e9},#4.484e9 -up},#{'F01_min':5.45525e9},#5.45678
                    'P':
                     {
                    'nndac_coil_id':10,#4,
                    'awg_tek_coil_channel':3,
                    'coil_device_channel':3,
                     'P':None, 
                     }
                }},
          '6': {'r':{
                    'Fr': 7.4925e9, #8.528e9 first sample # second sample 7.373e9,# second sample 7.376e9,#6.8791e9,
                    'Fr_min': 7.4915e9,#6.734e9,#6.879e9,#6.82e9,
                    'Fr_max': 7.4935e9,# down 6.850e9,#7.304e9, ##6.76e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                    {'F01_min': 0.615e9 }, #4.1923e9# 4.17799e9 #4.467e9#4.464e9#4.203e9},#4.675e9},#4.484e9 -up},#{'F01_min':5.45525e9},#5.45678
                    'P':
                     {
                    'nndac_coil_id':10,#4,
                    'awg_tek_coil_channel':3,
                    'coil_device_channel':3,
                     'P':None, 
                     }
                }}
         }

L_mat=np.asarray([[0.76939763, -0.1522447600000001, -0.07305767000000007],
  [0.16715004, 0.69026974, -0.56578149],
  [-0.22264723999999997, 0.15251167, 0.50282611]])
phi0_vec = np.asarray([1.7158459319724217e-05, 0.003311514714469841, -0.001214951726275308])

 

qubit_id = '1'
#qubits = {qubit_id: qubit for qubit_id, qubit in qubits.items() if qubit_id == '2'}
qubits = {qubit_id: qubit for qubit_id, qubit in qubits.items()}
switch_to_sample = {'1':1, '2':6}
sample_name = 'Fluxonium_1907_063_2'
#coil_control_channels = [1,2,3]
#it should be dumped too
#qubits_dump = {"qubits":qubit_params,'switch':switch_to_sample}
#qjson.dump('qubits','qubit_params',qubits_dump)

# %%
def set_qubit_fluxes(fluxes):
    zero_flux = np.asarray([L[i,i]*I0[i] for i in range(len(qubits))])
    fluxes_corrected = fluxes+zero_flux
    currents = np.linalg.solve(L, fluxes_corrected)
    
    for qubit_id_numerical, qubit_name in enumerate(['1', '2', '3']):
        qubit_coil_id = qubits[qubit_name]['q']['nndac_coil_id']
        dac.set_voltage(currents[qubit_id_numerical], channel=qubit_coil_id)
        
    print(currents, fluxes_corrected)

# %%
current_src1 = Yokogawa_GS210(address='GPIB1::1::INSTR')

# %%
lo1 = Agilent_E8257D('lo1', address = 'TCPIP0::10.20.61.10::inst0::INSTR')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %%
#pna = Agilent_N5242A('pna', address = 'TCPIP0::10.20.61.161::inst0::INSTR')

# %%
pna = RS_ZNB20('pna', address = 'TCPIP0::10.20.61.161::inst0::INSTR')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %% [markdown]
# # Спектроскопия

# %%
# RF switch for making sure we know what sample we are measuring
#pna = Agilent_N5242A('pna', address = 'TCPIP0::10.20.61.48::inst0::INSTR')
#lo1 = Agilent_E8257D('lo1', address = 'TCPIP0::10.20.61.59::inst0::INSTR')
#rf_switch = nn_rf_switch('rf_switch', address='10.20.61.224')
CHASSIS = 0
SLOT_AWG1 = 3
SLOT_AWG2 = 5

#awg_tek = Tektronix_AWG5014('awg_tek', address = 'TCPIP0::10.20.61.186::inst0::INSTR')

#sa = Agilent_N9030A('pxa', address = 'TCPIP0::10.20.61.56::inst0::INSTR')


lo_ex = lo1
lo_ro = pna
lo1._visainstrument.timeout = 5000

# %%
#sa = Agilent_N9030A('pxa', address = 'TCPIP0::10.20.61.56::inst0::INSTR')

# %%
awg1 = Keysight_M3202A_S('awg1', CHASSIS, SLOT_AWG1)
awg2 = Keysight_M3202A_S('awg2', CHASSIS, SLOT_AWG2)
awg1.get_clock = lambda: 1e9
awg2.get_clock = lambda: 1e9
# adc = instruments.Spectrum_M4i22xx('adc')

# %%
adc_device = TSW14J56_evm()
adc_device.timeout = 10
adc = TSW14J56_evm_reducer(adc_device)
adc.output_raw = True
adc.last_cov = False
adc.avg_cov = False
adc.resultnumber = False

adc_device.set_trig_src_period(100*125) # 10 kHz period rate
adc_device.set_trig_src_width(2) # 80 ns trigger length
# Out:
# ADS54J40 already programmed

# %%
#dac = nndac('TCPIP0::10.20.61.12::1000::SOCKET')
#coil_device = awg_tek
#coil_device = dac
coil_device = current_src1

# %%
db = database.MyDatabase()

sweeper = sweep_extras.Sweeper(db, sample_name=sample_name)
exdir_db_inst = exdir_db.Exdir_db(db=db, sample_name=sample_name)

# %% [markdown]
# # Mixer bypass

# %%
# когда спектроскопия не рабтает и всё плохо, тыкай сюды!
# вектнй анлизатр цепей - в режим свипа по частоте
pna.set_sweep_mode("LIN")
# смесители - открыть
#awg_tek = awg 
#for channel in range(0,4):
#awg._visainstrument.write('AWGC:DOUT1 OFF')
#awg._visainstrument.write('AWGC:DOUT2 OFF')
#awg._visainstrument.write('AWGC:DOUT3 OFF')
#awg._visainstrument.write('AWGC:DOUT4 OFF')
awg2.trigger_source_types = [0,6,6,6]
awg2.trigger_source_channels = [0, 4000,4000,4000]
awg2.trigger_delays = [30+10,7+10,7+10,7+10]
awg2.trigger_behaviours = [0,4,4,4]
awg2.set_trigger_mode(2)
awg1.set_trigger_mode(2)
awg1.trigger_source_types = [6,6,6,6]
awg1.trigger_source_channels = [4000, 4000,4000,4000]
awg1.trigger_delays = [7+10,7+10,7+10,7+10] # wait 60 ns for sync with awg2
awg1.trigger_behaviours = [4,4,4,4]
awg1.stop()
awg2.stop()
for channel in range(0,4):
    awg2.set_amplitude(0.05, channel=channel)
    awg2.set_offset(0.7,channel=channel)
    awg2.set_output(1, channel=channel)
    awg2.set_waveform(waveform = [0]*99500, channel=channel)
for channel in range(0,4):
    awg1.set_amplitude(0.03, channel=channel)
    awg1.set_offset(0.7,channel=channel)
    awg1.set_output(1, channel=channel)
    awg1.set_waveform(waveform =[0]*99500, channel=channel)
awg_tek.stop()
#for channel in range(1,5):
    #awg_tek.set_output(0, channel=channel)
    #awg_tek.set_amplitude(1.0, channel=channel)
    #awg_tek.set_offset(0.0,channel=channel)
    #awg_tek.set_output(1, channel=channel)
    #awg_tek.set_waveform([0]*99500, channel=channel)
awg2.set_marker(length=200, delay=0, channel=0, pxi_channels=1)
awg1.set_marker(length=200, delay=0, channel=0, pxi_channels=2)
awg2.run()
awg1.run()
#     

# Задаём постояннmtые смещения на каналы 1 и 3
#awg_tek.set_waveform([0]*awg_tek.get_nop(), channel=1)
#awg_tek.set_waveform([0]*awg_tek.get_nop(), channel=2)
#awg_tek.set_waveform([0]*awg_tek.get_nop(), channel=3)
#awg_tek.set_waveform([0]*awg_tek.get_nop(), channel=4)

# %%
#coil_device.set_waveform([0]*coil_device.get_nop(), channel=1)

# %%
#coil_device.get_nop()

# %% [markdown]
# # Резонаторная спектроскопия

# %% [markdown]
# ### Одномерный скан при фиксированном токе

# %% [markdown]
# ## Overview

# %%
coil_device.set_current(0.00)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# True

# %%
coil_device.set_src_mode_curr()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# True

# %%
coil_device.set_voltage_limits(10)
# Out:
# Go in voltage mode first.
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %%
coil_device.set_range(0.01)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# True

# %%
currents = arange(-1.,1, 0.02)*1e-3

pna_preset = True

#cs = Yokogawa_GS210(address='GPIB1::1::INSTR')
#pna = Agilent_N5242A('pna', address = 'ZVB20-23-100170')
coil_device.set_range(0.01)
if pna_preset:
    pna.set_power(-50.)
    pna.set_bandwidth(400)
    pna.set_centerfreq(6.87656e9)
    pna.set_span(100e6)

coil_device.set_status(1)
sweeper.sweep(pna, (currents, coil_device.set_current, 'Current'))
coil_device.set_status(0)
pna.close()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-08860d2782f0> in <module>()
#      13
#      14 coil_device.set_status(1)
# ---> 15 sweeper.sweep(pna, (currents, coil_device.set_current, 'Current'))
#      16 coil_device.set_status(0)
#      17 pna.close()
#
# C:\qtlab_replacement\qsweepy\sweep_extras.py in sweep(self, on_start, on_update, on_finish, *args, **kwargs)
#      64                            on_finish=on_finish+self.on_finish,
#      65                            on_update=on_update+self.on_update,
# ---> 66                            **kwargs)
#      67
#      68     def sweep_fit_dataset_1d_onfly(self, *args, on_start=[], on_update=[], on_finish=[], fitter_arguments=tuple(), **kwargs):
#
# C:\qtlab_replacement\qsweepy\sweep.py in sweep(measurer, shuffle, on_start, on_update, on_finish, use_deferred, ignore_callback_errors, *parameters, **kwargs)
#     204             if changed:
#     205                 setter_start = time.time()
# --> 206                 sweep_parameter.setter(value)
#     207                 sweep_parameter.setter_time += time.time() - setter_start
#     208         #measuring
#
# C:\qtlab_replacement\qsweepy\instrument.py in <lambda>(val, **lopts)
#     319                                 func = lambda val, **lopts: self.set(name, val, channel=ch, **lopts)
#     320                         else:
# --> 321                                 func = lambda val, **lopts: self.set(name, val, **lopts)
#     322
#     323                         func.__doc__ = 'Set variable %s' % name
#
# C:\qtlab_replacement\qsweepy\instrument.py in set(self, name, value, fast, **kwargs)
#     969
#     970                 else:
# --> 971                         val = self._set_value(name, value, **kwargs)
#     972                         if val is not None:
#     973                                 changed[name] = val
#
# C:\qtlab_replacement\qsweepy\instrument.py in _set_value(self, name, value, **kwargs)
#     920
#     921                 else:
# --> 922                         ret = func(value, **kwargs)
#     923
#     924                 if p['flags'] & self.FLAG_GET_AFTER_SET:
#
# C:\qtlab_replacement\qsweepy\instrument_drivers\Yokogawa_GS200.py in do_set_current(self, current)
#     112                 if (self._mincurrent <= current <= self._maxcurrent):
#     113                         self._visainstrument.write("SOUR:LEVEL %e"%current)
# --> 114                         sys.stdout.flush()
#     115                 else:
#     116                         print("Error: current limits,",(self._mincurrent, self._maxcurrent)," exceeded.")
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in flush(self)
#     340                 self.pub_thread.schedule(evt.set)
#     341                 # and give a timeout to avoid
# --> 342                 if not evt.wait(self.flush_timeout):
#     343                     # write directly to __stderr__ instead of warning because
#     344                     # if this is happening sys.stderr may be the problem.
#
# C:\ProgramData\Anaconda3\lib\threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# C:\ProgramData\Anaconda3\lib\threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
lo1.set_status(0)
pna.set_status(1)
pna.set_power(-45) # 
pna.set_nop(501)
pna.set_bandwidth(100)
pna.set_xlim(4.70e9, 7.7e9)
#pna.set_bandwidth(100)
freqs = pna.get_freqpoints()
S21 = pna.get_tracedata()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %%
plt.plot(S21,freqs)

# %%
## All anticrossings in same scan

# %%
#pna.get_points()['S-parameter'][0][1]
# pna.set_power(-10)
# pna.set_bandwidth(200)
pna.pre_sweep()
plt.figure()
plt.plot(pna.get_points()['S-parameter'][0][1],np.log10(np.abs(pna.measure()['S-parameter']))*10)
pna.post_sweep()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %%
plt.close('all')

# %% [markdown]
# ## Resonator control (N*M) anticrossing scan

# %%
pna.get_power()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# -55.0

# %% [markdown]
# ### Working anticrossing

# %%
import time

# %%
coil_device.set_range(0.01)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# True

# %%
coil_device.set_current(0.00)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# True

# %%
coil_device.set_status(0)
# Out:
# True

# %% [markdown]
# # Working anticrossing Yokogawa

# %%
if coil_device != current_src1:
    if coil_device ==awg_tek:
        raise ValueError('awg_tek is the active coil control device. This cell is for current_src1 (Yokogawa)')
    if coil_device ==dac:
        raise ValueError('dac is the active coil control device. This cell is for current_src1 (Yokogawa).')
#coil = 'z1'

#qubit_id='1'
current_max = -3.0e-3 # 7 mA - max on coil
#voltage_max = 1
current_nop =301
current_nop =181
currents=np.linspace(-current_max,current_max,current_nop)
#voltages=np.linspace(-voltage_max,voltage_max,current_nop)
#current_src1.set_status(1)
pna.set_nop(51)
pna.set_bandwidth(50)
pna.set_power(qubits[qubit_id]['r']['P'])
lo1.set_status(0)

pna.set_power(-55) #-30

def sleep(x):
    coil_device.set_current(x)
    #time.sleep(4)
for qubit_id in ['6']: #,'2','3','4','5','6']: '1','4','5',
        coil_device.set_status(1)
        coil_device.set_current(0)
        coil = 'DC_coil_5'
        #coil = 'Yokogawa-'+qubit_id
        #pna.set_nop((qubits[qubit_id]['r']['Fr_max']-qubits[qubit_id]['r']['Fr_min'])/qubits[qubit_id]['r']['dFr']+1)
        #pna.set_xlim(qubits[qubit_id]['r']['Fr_min'], qubits[qubit_id]['r']['Fr_max'])
        #pna.set_xlim(7.253e9, 7.2546e9)
        pna.set_xlim(7.4922e9, 7.4928e9)
        result = sweeper.sweep(pna, 
                        (currents, lambda x: sleep(x), 'Coil #{} current, qubit{}'.format(coil,qubit_id)), 
                        #sample_name=sample_name,
                        #sample_name='Fluxonium_1907_063_2',
                        measurement_type='resonator_anticrossing',
                        metadata={'qubit':qubit_id,'coil':coil,'pna_power':pna.get_power(),'sample_name':sample_name})
        coil_device.set_current(0)#0)
        coil_device.set_status(0)
lo1.set_status(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# load time:  0.041008710861206055
# pre_trace_time:  0.0009953975677490234
# trace 0 time:  0.026987552642822266
# trace 1 time:  0.05097007751464844
# trace 2 time:  0.0739583969116211
# trace 3 time:  0.09694814682006836
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\memmap.py:335: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# True

# %%
pna.get_power()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# -50.0

# %%
#coil_device = dac

# %%
if coil_device != dac:
    raise ValueError('awg_tek is the active coil control device. This cell is for nndac.')
#coil = 'z1'
#current_max = 1.5e-3
voltage_max = -2.0
current_nop = 101
#current_nop = 51
nndac_channels = [17]#[0]#[1]#[18,20]#[18, 20, 16]#[21,1,7]
#awg_tek_channels = [1,2,3]
#currents=np.linspace(-current_max,current_max,current_nop)
#voltages=np.linspace(-voltage_max,voltage_max,current_nop)
voltages=np.linspace(-voltage_max,voltage_max,current_nop)
#current_src1.set_status(1)
pna.set_nop(101)
pna.set_bandwidth(200)
#pna.set_power(qubits[qubit_id]['r']['P']+55) 
pna.set_power(-65) #-30
lo1.set_status(0)
def sleep(x,channel):
    dac.set_voltage(x, channel=channel)
    #time.sleep(4)
for nndac_channel_id in nndac_channels:
    for qubit_id in ['6']:#,'2','3','4','5','6']:
        dac.set_voltage(0, channel=nndac_channel_id)
        coil = 'NNDAC-'+str(nndac_channel_id)
        
        #pna.set_nop((qubits[qubit_id]['r']['Fr_max']-qubits[qubit_id]['r']['Fr_min'])/qubits[qubit_id]['r']['dFr']+1)
        pna.set_xlim(qubits[qubit_id]['r']['Fr_min'], qubits[qubit_id]['r']['Fr_max'])
        result = sweeper.sweep(pna, 
                        (voltages, lambda x: sleep(x, channel=nndac_channel_id), 'Coil #{} voltage, qubit{}'.format(coil,qubit_id)), 
                        sample_name=sample_name, 
                        measurement_type='resonator_anticrossing',
                        metadata={'qubit':qubit_id,'awg_tek_channels':coil_device_channels,'pna_power':pna.get_power()})
                               #filename='Fluxonium 1902-057-2 Coil #{} anticrossings qubit {}'.format(coil, qubit_id))
        for nndac_channel in range(24):
            dac.set_voltage(0, channel=nndac_channel)#0)
lo1.set_status(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-796eb7a36635> in <module>()
# ----> 1 if coil_device != dac:
#       2     raise ValueError('awg_tek is the active coil control device. This cell is for nndac.')
#       3 #coil = 'z1'
#       4 #current_max = 1.5e-3
#       5 voltage_max = -2.0
#
# NameError: name 'dac' is not defined

# %%
dac.set_voltage(-0.00, channel=17)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %%
qubits['6']['r']['Fr_min']
# Out:
# 8480000000.0

# %%
if coil_device != awg_tek:
    raise ValueError('awg_tek is not the active coil control device. This cell is for awg_tek.')
#coil = 'z1'
#current_max = 1.5e-3
voltage_max = 1.5
current_nop = 201

# nndac_channels = [6,8,10]#[18,20]#[18, 20, 16]#[21,1,7]
awg_tek_channels = [4]
coil_device_channels = [4]#3]
#currents=np.linspace(-current_max,current_max,current_nop)
voltages=np.linspace(-voltage_max,voltage_max,current_nop)
#voltages=np.linspace(-0.5,voltage_max,current_nop)
#current_src1.set_status(1)
pna.set_nop(401)
pna.set_bandwidth(200)
pna.set_power(-60)
lo1.set_status(0)
pna.set_status(1)
for coil_device_channel in coil_device_channels:
    for qubit_id in ['1']:
        coil = 'coil_device_channel-'+str(coil_device_channel)
        coil_device.set_output(1, channel=coil_device_channel)
        #pna.set_nop((qubits[qubit_id]['r']['Fr_max']-qubits[qubit_id]['r']['Fr_min'])/qubits[qubit_id]['r']['dFr']+1)
        pna.set_nop(41)
        #pna.set_xlim(qubits[qubit_id]['r']['Fr_min'], qubits[qubit_id]['r']['Fr_max'])
        pna.set_xlim(7.395e9, 7.420e9)
        result = sweeper.sweep(pna,
                        (voltages, lambda x: coil_device.set_offset(x, channel=coil_device_channel) , 'Coil'),
                        sample_name=sample_name, 
                        measurement_type='resonator_anticrossing',
                        metadata={'qubit':qubit_id,'awg_tek_channels':coil_device_channels,'pna_power':pna.get_power()})
        
        #dac.set_voltage(0, channel=6)#0)
        #dac.set_voltage(0, channel=8)#2)
        #dac.set_voltage(0, channel=10)#4)
        coil_device.set_output(0, channel=coil_device_channel)
        for coil_device_channel2 in coil_device_channels:
            coil_device.set_offset(0, channel=coil_device_channel2)
lo1.set_status(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7833d905ff3c> in <module>()
# ----> 1 if coil_device != awg_tek:
#       2     raise ValueError('awg_tek is not the active coil control device. This cell is for awg_tek.')
#       3 #coil = 'z1'
#       4 #current_max = 1.5e-3
#       5 voltage_max = 1.5
#
# NameError: name 'awg_tek' is not defined

# %% [markdown]
# ## anticrossings with two simultaneous applied coils for non-diagonal coils

# %%
coil_device.get_status(channel=1)
# Out:
# True

# %%
coil_device.run()

# %%
if coil_device != awg_tek:
    raise ValueError('awg_tek is not the active coil control device. This cell is for awg_tek.')

anticrossing_matrix = []
files_matrix_location = []
voltage_max = 2
current_nop = 401
coil_device_channels = [1,2,3]
voltages=np.linspace(-voltage_max,voltage_max,current_nop)
pna.set_nop(401)
pna.set_bandwidth(500)
pna.set_power(qubits[qubit_id]['r']['P']+40) 
lo1.set_status(0)
for coil_device_channel in coil_device_channels:
    anticrossing_row = []
    files_location_row = []
    for qubit_id in ['1', '2', '3']:
        # if we are in the main coil for the current qubit, sweep only the main coil.
        if qubits[qubit_id]['q']['P']['coil_device_channel'] == coil_device_channel:
            coil = 'coil_device_channel-('+str(coil_device_channel)+')'
            def setter(x):
                coil_device.set_offset(x, channel=coil_device_channel)
        # if we are probing a non-diagonal matrix element (non-main coil), sweep the main simultaneously.
        # this helps to identify the sign of the mutual matrix element.
        else:
            coil = 'coil_device_channel-('+str(coil_device_channel)+')+('+\
                                           str(qubits[qubit_id]['q']['P']['coil_device_channel'])+')'
            coil_device.set_output(1, channel=qubits[qubit_id]['q']['P']['coil_device_channel'])
            def setter(x):
                coil_device.set_offset(x, channel=coil_device_channel)
                coil_device.set_offset(x, channel=qubits[qubit_id]['q']['P']['coil_device_channel'])
        
        coil_device.set_output(1, channel=coil_device_channel)
        pna.set_nop((qubits[qubit_id]['r']['Fr_max']-qubits[qubit_id]['r']['Fr_min'])/qubits[qubit_id]['r']['dFr']+1)
        pna.set_xlim(qubits[qubit_id]['r']['Fr_min'], qubits[qubit_id]['r']['Fr_max'])
        result,loc = sweep.sweep(pna, 
                        (voltages, setter, '#{} voltage, qubit{}'.format(coil,qubit_id)), 
                        filename=sample_name+' #{} anticrossings qubit {}'.format(coil, qubit_id),loc=True)
#         loc+=sample_name+' #{} anticrossings qubit {}'.format(coil, qubit_id)+'.pkl'
        files_location_row.append(loc)
        anticrossing_row.append(result['S-parameter'])
        
        
        for coil_device_channel2 in coil_device_channels:
            coil_device.set_offset(0, channel=coil_device_channel2)
    anticrossing_matrix.append(anticrossing_row)
    files_matrix_location.append(files_location_row)
lo1.set_status(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-07ec35f66308> in <module>()
#       1 if coil_device != awg_tek:
# ----> 2     raise ValueError('awg_tek is not the active coil control device. This cell is for awg_tek.')
#       3
#       4 anticrossing_matrix = []
#       5 files_matrix_location = []
#
# ValueError: awg_tek is not the active coil control device. This cell is for awg_tek.

# %%
import locale
# Set to German locale to get comma decimal separater
locale.setlocale(locale.LC_NUMERIC, "deu_DEU")

import numpy as np
import matplotlib.pyplot as plt
plt.rcdefaults()

# Tell matplotlib to use the locale we set above
plt.rcParams['axes.formatter.use_locale'] = True
# %matplotlib qt5

figs, axes = plt.subplots(3,3, figsize=(9,6), sharex=True, sharey='row')

delays = []
locations = files_matrix_location
for row_id in range(len(locations)):
    for column_id in range(len(locations[0])):
        file = open(locations[row_id][column_id],'rb')
        data = pickle.load(file)
        data = data[1]['S-parameter']
        unwrapped = np.unwrap(np.angle(data[2])).T
        delays.append((unwrapped[-1,:]-unwrapped[0,:]+np.pi*2)/(data[1][1][-1]-data[1][1][0]))
delay = np.median(delays)



anticrossing_matrix = []
max_dev_matrix = []
coil_value_matrix = []

for row_id in range(len(locations)):
    anticrossing_row = []
    max_dev_row = []
    coil_value_row = []
    for column_id in range(len(locations[0])):
        file = open(locations[row_id][column_id],'rb')
        data = pickle.load(file)
        data = data[1]['S-parameter']
        data_nodelay = (data[2]*np.exp(-1j*delay*data[1][1])).T
        data_deviation_complex = data_nodelay - np.mean(data_nodelay, axis=0)
        axes[column_id, row_id].pcolormesh(data[1][0], data[1][1]/1e9, np.abs(data_deviation_complex), cmap='RdBu')
        max_dev = data[1][1][np.argmax(np.abs(data_deviation_complex), axis=0)]/1e9
        axes[column_id, row_id].plot(data[1][0], max_dev, color='yellow', linewidth=2)
        if column_id == 0:
            axes[column_id, row_id].set_title('Линия #'+str(row_id+1))
        if row_id == 0:
            axes[column_id, row_id].set_ylabel('Резонатор #'+str(column_id+1))
        anticrossing_row.append(data_deviation_complex)
        max_dev_row.append(max_dev)
        coil_value_row.append(data[1][0])
    anticrossing_matrix.append(anticrossing_row)
    max_dev_matrix.append(max_dev_row)
    coil_value_matrix.append(coil_value_row)
figs.text(0.5, 0.04, 'Напряжение управляющей линии, В', ha='center')
figs.text(0.02, 0.5, 'Частота, ГГц', va='center', rotation='vertical')
#plt.tight_layout()
print (delay/2/np.pi)
# Out:
# -4.1937387595416584e-08

# %%
fqb = lambda x, EJ1, EJ2, EC, phi0, L: (8*EC)**0.5*((EJ1-EJ2)**2*np.sin(np.pi*x*L+phi0*np.pi)**2+(EJ1+EJ2)**2*np.cos(np.pi*x*L+phi0*np.pi)**2)**0.25
fr  = lambda x, frb, g, EJ1, EJ2, EC, phi0, L: (fqb(x, EJ1, EJ2, EC, phi0, L)+frb)*0.5+(((fqb(x, EJ1, EJ2, EC, phi0, L)-frb)*0.5)**2+g**2)**0.5*np.sign(frb-fqb(x, EJ1, EJ2, EC, phi0, L))

# %%
num_resonators=3

# %%
L_mat=np.asarray([[ 0.31*3, -0.07*3+0.31*3, -0.02*3+0.31*3],
        [ 0.08*3+0.29*3,  0.29*3, -0.13*3+0.29*3],
        [-0.08*3,  0.07*3+0.14*3,  0.14*3]])
phi0 = np.asarray([-0.02, -0.025, -0.038])

initial_guess = {'L':L_mat,#np.identity(num_resonators)*0.3-0.01, # initial guess for inductance matrix
                     'phi0':phi0,#-np.ones(num_resonators)*0.1, # initial guess for residual flux
                     'frb':np.mean(max_dev_matrix, axis=(0,2))*1e9,
                     #'frb':[6.85e9, 7.15e9, 7.00e9],
                     'EC':0.175e9,
                     'EJ1':18.8e9,
                     'EJ2':3.6e9,
                     'g':40e6}

phi0_vec = []
L_mat = []
fitresults_vec = []
for resonator_id in range(num_resonators):
    data = [max_dev_matrix[i][resonator_id] for i in range(num_resonators)]
    x = [coil_value_matrix[i][resonator_id] for i in range(num_resonators)]
    def fr_coil(p, coil_id):
        frb, g, EJ1, EJ2, EC, phi0 = p[:6]
        L = p[6:]
        return fr(x[coil_id], frb, g, EJ1, EJ2, EC, phi0, L[coil_id])/1e9
    def residuals(p):
        frb, g, EJ1, EJ2, EC, phi0 = p[:6]
        L = p[6:]
        res = []
        for coil_id in range(len(data)):
            #print (fr(x[coil_id], frb, g, EJ1, EJ2, EC, phi0, L[coil_id]))
            #print (fqb(x[coil_id], EJ1, EJ2, EC, phi0, L[coil_id]))
            #print (x[coil_id]*np.reshape(L,(-1,1)))
            res.extend((fr(x[coil_id], frb, g, EJ1, EJ2, EC, phi0, L[coil_id])/1e9-data[coil_id])*(3 if coil_id == resonator_id else 1))
        return res
    from scipy.optimize import least_squares

    p0 = (initial_guess['frb'][resonator_id], 
          initial_guess['g'], 
          initial_guess['EJ1'], 
          initial_guess['EJ2'], 
          initial_guess['EC'], 
          initial_guess['phi0'][resonator_id])+\
          tuple(initial_guess['L'][resonator_id,:])

    bounds = ((0,      0,      0,      0,      0,      -np.pi)+tuple([-np.inf]*num_resonators),
              (np.inf, np.inf, np.inf, np.inf, np.inf,  np.pi)+tuple([ np.inf]*num_resonators))
    fitresults = least_squares(residuals, p0, x_scale=np.abs(p0), bounds=bounds)
    fitresults_vec.append(fitresults)
    phi0_vec.append(fitresults.x[5])
    L_mat.append(fitresults.x[6:])
    #print (fitresults.x)

# %%
for resonator_id in range(num_resonators):
    for coil_id in range(num_resonators):
        axes[resonator_id, coil_id].plot(coil_value_matrix[coil_id][resonator_id], 
                                     fr_coil(fitresults_vec[resonator_id].x, coil_id), color='black', linewidth=2)

# %%
L_mat = [[ 0.76939763,  0.61715287,  0.69633996],
        [ 0.85741978,  0.69026974,  0.12448825],
        [ 0.28017887,  0.65533778,  0.50282611]]
phi0_vec = [1.7158459319724217e-05, 0.003311514714469841, -0.001214951726275308]

# %%
np.asarray(L_mat), phi0_vec
# Out:
# (array([[ 0.76939763,  0.61715287,  0.69633996],
#         [ 0.85741978,  0.69026974,  0.12448825],
#         [-0.28017887,  0.65533778,  0.50282611]]),
#  [1.7158459319724217e-05, 0.003311514714469841, -0.001214951726275308])

# %%
np.asarray(L_mat), phi0_vec
# Out:
# (array([[ 2.42716905,  1.94809884,  2.28459943],
#         [ 2.70767567,  2.17341361,  1.07013558],
#         [-0.25804204,  1.45064228,  0.98295875]]),
#  [-0.000997235991072193, -0.001102774408547372, -0.0026798743884506493])

# %%
for row_id in range(len(L_mat)):
    for col_id in range(len(L_mat)):
        if row_id != col_id:
            L_mat[row_id][col_id]-=L_mat[row_id][row_id]

# %%
L_mat, phi0_vec
# Out:
# ([[0.76939763, -0.1522447600000001, -0.07305767000000007],
#   [0.16715004, 0.69026974, -0.56578149],
#   [-0.22264723999999997, 0.15251167, 0.50282611]],
#  [1.7158459319724217e-05, 0.003311514714469841, -0.001214951726275308])

# %%
L_mat, phi0_vec
# Out:
# ([array([ 0.76939763, -0.15224476, -0.07305767]),
#   array([ 0.16715005,  0.69026974, -0.56578149]),
#   array([-0.78300498,  0.15251167,  0.50282611])],
#  [1.7158459319724217e-05, 0.003311514714469841, -0.001214951726275308])

# %%
L_mat
# Out:
# [array([ 2.42716905, -0.47907021, -0.14256962]),
#  array([ 0.53426206,  2.17341361, -1.10327803]),
#  array([-1.2410008 ,  0.46768353,  0.98295875])]

# %%
L_mat=np.asarray([[ 2.4316565 , -0.47950326, -0.14150814],
 [ 0.53928393,  2.17353468, -1.09987528],
 [-1.23003529,  0.49316206,  0.96886678]])
phi0_vec = np.asarray([-0.000997235991072193, -0.001102774408547372, -0.0026798743884506493])

# %%
L_mat=np.asarray([[ 0.76939763, -0.15224476, -0.07305767],
  [ 0.16715005,  0.69026974, -0.56578149],
  [-0.78300498,  0.15251167,  0.50282611]])
phi0_vec = np.asarray([1.7158459319724217e-05, 0.003311514714469841, -0.001214951726275308])

# %%
L_mat=np.asarray([[0.76939763, -0.1522447600000001, -0.07305767000000007],
  [0.16715004, 0.69026974, -0.56578149],
  [-0.22264723999999997, 0.15251167, 0.50282611]])
phi0_vec = np.asarray([1.7158459319724217e-05, 0.003311514714469841, -0.001214951726275308])

# %%
np.dot(np.linalg.inv(L_mat), phi0_vec)
print(np.dot(np.linalg.inv(L_mat), -np.asarray(phi0_vec)+np.asarray([0.5, 0.0, -0.5])))
print(np.dot(np.linalg.inv(L_mat), -np.asarray(phi0_vec)+np.asarray([0.5, 0.0, 0.5])))
# Out:
# [ 0.62477613 -0.13751953  0.02265417]
# [1.19994477 1.64441821 2.36659293]

# %%
np.dot(np.linalg.inv(L_mat), -np.asarray(phi0_vec)+np.asarray([0.5, 0.0, -0.5]))
# Out:
# array([ 0.4724919 , -0.60931336, -0.59793759])

# %%
np.dot(np.linalg.inv(L_mat), -np.asarray(phi0_vec)+np.asarray([0.0, 0.5, 0.0]))
# Out:
# array([0.1374976 , 0.69176241, 0.0067109 ])

# %% [markdown]
# ## Function to find the resonator for two-tone scans

# %%
def find_resonator(resonator_id, criterion='max_dev_complex', delay=0, check=1, raise_on_error=True): 
#    print ('resonator_id: ', resonator_id)
    # turn of all second tones
    lo1_status = lo1.get_status()
    lo1.set_status(0)
    # prior bandwidth
    bandwidth = pna.get_bandwidth()
    pna.set_bandwidth(100)
    average = pna.get_average()
    pna.set_average(0)
    #pna.set_power(-60)
    #pna.set_nop(501)
    nop = pna.get_nop()
    xlim = pna.get_xlim()
    pna.set_nop((qubits[resonator_id]['r']['Fr_max']-
                 qubits[resonator_id]['r']['Fr_min'])/qubits[resonator_id]['r']['dFr']+1)
    pna.set_xlim(qubits[resonator_id]['r']['Fr_min'], qubits[resonator_id]['r']['Fr_max'])
    #current_src1.set_current(current)
    
    # measure S21
    results = []
    for iteration_id in range(check+1):
        S21 = pna.measure()['S-parameter']
        freqs = pna.get_points()['S-parameter'][0][1]
    
        if (criterion == 'max_dev_complex'):
            measurement = S21*np.exp(2*np.pi*1j*freqs*delay)
            #plt.figure()
            #plt.plot(freqs, np.real(measurement-np.mean(measurement)))
            #plt.plot(freqs, np.imag(measurement-np.mean(measurement)))
            #plt.plot(freqs, np.abs(measurement-np.mean(measurement)))
            results.append(freqs[np.argmax(np.abs(measurement-np.mean(measurement)))])
        if (criterion == 'min_abs'):
            measurement = np.abs(S21)
            results.append(freqs[np.argmin(measurement)])
    # if resonator is off by more 3 times tolerance, raise if raise_on_error, otherwise warn
    if (np.std(results)>qubits[resonator_id]['r']['dFr']*10):
        if raise_on_error:
            raise Exception('Could not find resonator')
        else:
            print ('Could not find resonator')
    else: 
        print('resonator found at '+str(np.mean(results)))
        
    lo1.set_status(lo1_status)
    pna.set_bandwidth(bandwidth)
    pna.set_average(average)
    pna.set_nop(nop)
    pna.set_xlim(*xlim)
    
    return np.mean(results)

# %%
qubits[qubit_id]['r']['Fr']
# Out:
# 7324000000.0

# %%
qubit_id='2'
pna.set_power(-30)
delay = 70e-9
pna.pre_sweep()
res_freq = find_resonator(qubit_id, criterion='max_dev_complex', delay=delay, check=1, raise_on_error=False)
pna.post_sweep()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# resonator found at 7891000000.0

# %%
nndac_channel_id
# Out:
# 1

# %% [markdown]
# # Two-Tone Scan

# %%
voltage_max = 4
voltage_nop = 11#101#101#101
freq_nop =81#481#961#961#161 #961
nndac_channels = [1]#[6,8,10]#[0,2,4]

#voltages=np.linspace(-1.5, 1.5, voltage_nop)
#voltages=np.linspace(0.63, 1.5, voltage_nop)
voltages=np.linspace(0.4, 1.2, voltage_nop)
#voltages=np.linspace(-voltage_max,voltage_max,voltage_nop)
#freqs= np.linspace(0.2e9,5e9,freq_nop)
freqs= np.linspace(3.7e9,4.1e9,freq_nop)
pna.set_nop(1)
pna.set_bandwidth(20)
pna.set_power(-30)
base_power = -20
frequency_gain  = 0*6.8
lo1.set_power(5)
lo1.set_status(1)
delay = 70e-9
nndac_channel_id = 0
for qubit_id in ['2']:#['1', '3']:
    #for coil_control_channel in [qubits[qubit_id]['q']['P']['nndac_coil_id']]:
        coil_device_channel = qubits[qubit_id]['q']['P']['coil_device_channel']
        res_freq = qubits[qubit_id]['r']['Fr']
        pna.set_frequency(res_freq)
        pna.set_centerfreq(res_freq)
#for nndac_channel_id in nndac_channels:
#    for qubit_id in ['1', '2', '3']:
        #pna.set_power(qubits[qubit_id]['r']['P'])
        try: 
            #coil = 'NNDAC-'+str(nndac_channel_id)
            #dac.set_voltage(0, channel=0)
            #dac.set_voltage(0, channel=2)
            #dac.set_voltage(0, channel=4)
            #dac.set_voltage(qubits[qubit_id]['q']['P']['Fmin_coil_currents'][6], channel=6)
            #dac.set_voltage(qubits[qubit_id]['q']['P']['Fmin_coil_currents'][8], channel=8)
            #dac.set_voltage(qubits[qubit_id]['q']['P']['Fmin_coil_currents'][10], channel=10)
            def set_volt_res(x):
                coil_device.set_output(1, channel=coil_device_channel)
                awg_tek.set_offset(x, channel=coil_device_channel)
                #res_freq=(qubits[qubit_id]['r']['Fr_max']+qubits[qubit_id]['r']['Fr_min'])/2-(qubits[qubit_id]['r']['Fr_max']-qubits[qubit_id]['r']['Fr_min'])*x/3
                #pna.set_frequency(res_freq)
                #pna.set_centerfreq(res_freq)
                
                #dac.set_voltage(x, channel=nndac_channel_id)
                #res_freq = find_resonator(qubit_id, criterion='max_dev_complex', delay=delay,
                                          #check=1, raise_on_error=False)
                #pna.set_frequency(res_freq)
                #pna.set_centerfreq(res_freq)
            
            def set_corrected_frequency(x):
                lo1.set_frequency(x)
                lo1.set_power(x/1e9*frequency_gain+base_power)
            
            result = sweeper.sweep(pna,
                                 (voltages,#+qubits[qubit_id]['q']['P']['Fmin_coil_currents'][nndac_channel_id], 
                                  set_volt_res, 'Coil #{} voltage'.format(coil_device_channel)),
                                 (freqs,set_corrected_frequency, 'Excitation frequency', 'Hz'),
                                 sample_name=sample_name,
                                 measurement_type='tone_tone_spectroscopy',
                                 metadata = {'resonator_id': qubit_id,
                                             'probe_power': pna.get_power(),
                                             'base_pump_power': lo1.get_power(),
                                             'frequeny_gain': frequency_gain,
                                             'bw': pna.get_bandwidth(),
                                             'fr': res_freq,
                                             'coil_device_channel': coil_device_channel,
                                            })
            #dac.set_voltage(0,nndac_channel_id)
        except KeyboardInterrupt:
            #for nndac_channel in nndac_channels:
                #dac.set_voltage(0,nndac_channel)
            raise
        finally:
            for nndac_channel in nndac_channels:
                dac.set_voltage(0,nndac_channel)
                set_volt_res(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# {}
# <bound method database.update_in_database of <qsweepy.database.database object at 0x000001D299EDC828>> start: 2019-04-25 09:13:55.834860, started/done/total sweeps: 0/891/891,
# Measured data:
# 'S-parameter': parameters: Coil #4 voltage (),:[0.4, 1.2] (11 points) with setter
# Excitation frequency (Hz),:[3700000000.0, 4100000000.0] (81 points) with setter
# Frequency (Hz),:[7410000000.0, 7410000000.0] (1 points) without setter
# data: [[[-0.00096888-0.00416064j]
#   [-0.00078789-0.00403878j]
#   [-0.00097657-0.00397022j]
#   [-0.0008321 -0.00407496j]
#   [-0.00067778-0.004403j  ]
#   [-0.00105339-0.00403074j]
#   [-0.00092558-0.00436861j]
#   [-0.00069989-0.00414701j]
#   [-0.00084571-0.0044322j ]
#   [-0.00099158-0.00433002j]
#   [-0.00076476-0.00441681j]
#   [-0.00098026-0.00438932j]
#   [-0.00087761-0.00458784j]
#   [-0.00100364-0.00415112j]
#   [-0.00121504-0.00463423j]
#   [-0.00074789-0.00485283j]
#   [-0.00128857-0.00474119j]
#   [-0.00090665-0.00467978j]
#   [-0.00095142-0.00484127j]
#   [-0.00119162-0.00485297j]
#   [-0.00102798-0.00459397j]
#   [-0.00102771-0.00440524j]
#   [-0.00080354-0.00451105j]
#   [-0.00122469-0.00483838j]
#   [-0.0008929 -0.00478047j]
#   [-0.00107673-0.00466272j]
#   [-0.0012616 -0.00455511j]
#   [-0.00111301-0.00481126j]
#   [-0.00093412-0.00427012j]
#   [-0.00134082-0.00471179j]
#   [-0.00101297-0.00449309j]
#   [-0.0013639 -0.00462929j]
#   [-0.0010553 -0.00495151j]
#   [-0.00121529-0.00449397j]
#   [-0.00108164-0.00458076j]
#   [-0.00097509-0.0043561j ]
#   [-0.00089624-0.0042721j ]
#   [-0.00105302-0.00406852j]
#   [-0.00057005-0.00435349j]
#   [-0.00094514-0.00401374j]
#   [-0.00085905-0.00375238j]
#   [-0.00118993-0.00372121j]
#   [-0.00106452-0.00353541j]
#   [-0.00101488-0.0036491j ]
#   [-0.00100384-0.00360875j]
#   [-0.0009954 -0.00351942j]
#   [-0.00084965-0.00341659j]
#   [-0.00103979-0.00361128j]
#   [-0.00121707-0.00358359j]
#   [-0.00142244-0.00358271j]
#   [-0.00122753-0.0032707j ]
#   [-0.00113847-0.00328392j]
#   [-0.00117916-0.0036557j ]
#   [-0.00121411-0.00320845j]
#   [-0.00120694-0.00342078j]
#   [-0.00135095-0.00326524j]]] (<qsweepy.database.database object at 0x000001D299EDC828>,)
# load_exdir: file open time:  0.0
# load_exdir: file open time:  0.0
# load_exdir: file open time:  0.0
# load time:  0.039995670318603516
# pre_trace_time:  0.0
# trace 0 time:  0.0299990177154541
# trace 1 time:  0.05999493598937988
# trace 2 time:  0.08998990058898926
# trace 3 time:  0.11998772621154785
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\memmap.py:335: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
awg_tek.set_offset(-0.14, channel=4)
awg_tek.set_output(1,channel=4)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# True

# %%
qubits[qubit_id]['q']['P']['coil_device_channel']
# Out:
# 4

# %%
## qubit_id='1'
#nndac_channel_id=qubits[qubit_id]['q']['P']['nndac_coil_id']

qubit_id='2'
freqs = np.arange(3.75e9, 3.85e9,0.5e6)
powers = np.arange(-20, 0.0, 2)
#powers =[5]
pna.set_nop(1)
# pna.set_xlim(Qubits[qubit_id]['r']['Fr'], Qubits[qubit_id]['r']['Fr'])
pna.set_bandwidth(5)
pna.set_power(-30)
delay = 70e-9
coil_device_channel = qubits[qubit_id]['q']['P']['coil_device_channel']
coil_voltage=0.4
awg_tek.set_offset(coil_voltage, channel=coil_device_channel)
awg_tek.set_output(1,channel=4)
#dac.set_voltage(-0.98, channel=21)
#dac.set_voltage(-2.57, channel=1)

res_freq = qubits[qubit_id]['r']['Fr']
pna.set_frequency(res_freq)
pna.set_centerfreq(res_freq)
#def set_volt_res():
    #for _qubit_id in ['1']:
        #for coil_channel_id, channel_voltage in qubits[_qubit_id]['q']['P']['Fmin_coil_currents'].items():
            #dac.set_voltage(channel_voltage, channel=nndac_channel_id)
            #coil_device.set_offset(channel_voltage, channel=coil_channel_id)
    #res_freq = find_resonator(qubit_id, criterion='max_dev_complex', delay=delay,
                                  #check=3, raise_on_error=False)
    #print(res_freq)
#set_volt_res()

lo1.set_status(1)
lo1.set_power(10)
result = sweeper.sweep(pna,
                     (powers,lo1.set_power,'two-tone power','dB'),
                     (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
                     sample_name=sample_name,
                     measurement_type='tone_tone_poverskan',
                     metadata = {'resonator_id': qubit_id,
                                 'probe_power': pna.get_power(),
                                 'base_pump_power': lo1.get_power(),
                                 'coil_voltage': coil_voltage,
                                 'bw': pna.get_bandwidth(),
                                 'fr': res_freq,
                                 'coil_device_channel': coil_device_channel,
                                })
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# {}
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# root: ERROR    Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-08265a033f32>", line 46, in <module>
#     'coil_device_channel': coil_device_channel,
#   File "C:\qtlab_replacement\qsweepy\sweep_extras.py", line 48, in sweep
#     return sweep.sweep(*args, on_start = self.on_start, on_finish = self.on_finish, on_update = self.on_update, **kwargs)
#   File "C:\qtlab_replacement\qsweepy\sweep.py", line 190, in sweep
#     mpoint = measurer.measure()
#   File "C:\qtlab_replacement\qsweepy\instrument_drivers\Agilent_N5242A.py", line 542, in measure
#     data = self.get_tracedata(format='realimag')
#   File "C:\qtlab_replacement\qsweepy\instrument_drivers\Agilent_N5242A.py", line 333, in get_tracedata
#     sleep(0.002)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\ProgramData\Anaconda3\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
awg_tek.set_offset(x, channel=coil_device_channel)
#

# %%
voltage_max = 4
voltage_nop = 61#101#101
freq_nop =501#961#161 #961
nndac_channels = [1]#[6,8,10]#[0,2,4]

#voltages=np.linspace(-1.5, 1.5, voltage_nop)
#voltages=np.linspace(0.63, 1.5, voltage_nop)
voltages=np.linspace(-1.5, 1.5, voltage_nop)
#voltages=np.linspace(-voltage_max,voltage_max,voltage_nop)
#freqs= np.linspace(0.2e9,5e9,freq_nop)
freqs= np.linspace(5e9,10e9,freq_nop)
pna.set_nop(1)
pna.set_bandwidth(20)
pna.set_power(-70)
base_power = 18
frequency_gain  = 0*6.8
lo1.set_power(5)
lo1.set_status(1)
delay = 70e-9
nndac_channel_id = 0
for qubit_id in ['2']:#['1', '3']:
    #for coil_control_channel in [qubits[qubit_id]['q']['P']['nndac_coil_id']]:
        coil_device_channel = qubits[qubit_id]['q']['P']['coil_device_channel']
        res_freq = qubits[qubit_id]['r']['Fr']
        pna.set_frequency(res_freq)
        pna.set_centerfreq(res_freq)
#for nndac_channel_id in nndac_channels:
#    for qubit_id in ['1', '2', '3']:
        #pna.set_power(qubits[qubit_id]['r']['P'])
        try: 
            #coil = 'NNDAC-'+str(nndac_channel_id)
            #dac.set_voltage(0, channel=0)
            #dac.set_voltage(0, channel=2)
            #dac.set_voltage(0, channel=4)
            #dac.set_voltage(qubits[qubit_id]['q']['P']['Fmin_coil_currents'][6], channel=6)
            #dac.set_voltage(qubits[qubit_id]['q']['P']['Fmin_coil_currents'][8], channel=8)
            #dac.set_voltage(qubits[qubit_id]['q']['P']['Fmin_coil_currents'][10], channel=10)
            def set_volt_res(x):
                coil_device.set_output(1, channel=coil_device_channel)
                awg_tek.set_offset(x, channel=coil_device_channel)
                res_freq=(qubits[qubit_id]['r']['Fr_max']+qubits[qubit_id]['r']['Fr_min'])/2-(qubits[qubit_id]['r']['Fr_max']-qubits[qubit_id]['r']['Fr_min'])*x/3
                pna.set_frequency(res_freq)
                pna.set_centerfreq(res_freq)
                #dac.set_voltage(x, channel=nndac_channel_id)
                #res_freq = find_resonator(qubit_id, criterion='max_dev_complex', delay=delay,
                                          #check=1, raise_on_error=False)
                #pna.set_frequency(res_freq)
                #pna.set_centerfreq(res_freq)
            
            def set_corrected_frequency(x):
                lo1.set_frequency(x)
                lo1.set_power(x/1e9*frequency_gain+base_power)
            
            result = sweeper.sweep(pna,
                                 (voltages,#+qubits[qubit_id]['q']['P']['Fmin_coil_currents'][nndac_channel_id], 
                                  set_volt_res, 'Coil #{} voltage'.format(coil_device_channel)),
                                 (freqs,set_corrected_frequency, 'Excitation frequency', 'Hz'),
                                 sample_name=sample_name,
                                 measurement_type='tone_tone_spectroscopy',
                                 metadata = {'resonator_id': qubit_id,
                                             'probe_power': pna.get_power(),
                                             'base_pump_power': lo1.get_power(),
                                             'frequeny_gain': frequency_gain,
                                             'bw': pna.get_bandwidth(),
                                             'fr': res_freq,
                                             'coil_device_channel': coil_device_channel,
                                            })
            #dac.set_voltage(0,nndac_channel_id)
        except KeyboardInterrupt:
            #for nndac_channel in nndac_channels:
                #dac.set_voltage(0,nndac_channel)
            raise
        finally:
            for nndac_channel in nndac_channels:
                dac.set_voltage(0,nndac_channel)
                set_volt_res(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# {}
# <bound method database.update_in_database of <qsweepy.database.database object at 0x000001D1314CC710>> start: 2019-04-24 02:32:35.967561, started/done/total sweeps: 0/30561/30561,
# Measured data:
# 'S-parameter': parameters: Coil #4 voltage (),:[-1.5, 1.5] (61 points) with setter
# Excitation frequency (Hz),:[5000000000.0, 10000000000.0] (501 points) with setter
# Frequency (Hz),:[7407500000.0, 7407500000.0] (1 points) without setter
# data: [[[-1.92671847-3.02924204j]
#   [-1.94752908-3.10255933j]
#   [-1.88720918-3.05454731j]
#   ...
#   [-1.91096711-3.17357016j]
#   [-1.9440974 -3.02941585j]
#   [-1.91559958-3.19610214j]]
#
#  [[-1.84821808-3.10039783j]
#   [-1.89863002-3.08679175j]
#   [-1.96063244-3.18328524j]
#   ...
#   [-1.86641335-3.01139307j]
#   [-1.92513406-3.02500868j]
#   [-1.89330947-3.0425601j ]]
#
#  [[-1.81379282-3.17884707j]
#   [-1.92038   -3.22048306j]
#   [-1.94522536-3.05767059j]
#   ...
#   [-1.90372705-3.15810633j]
#   [-1.75885332-3.1443491j ]
#   [-1.84777224-3.08964586j]]
#
#  ...
#
#  [[ 3.44399977-1.58675337j]
#   [ 3.38243484-1.47860312j]
#   [ 3.32136512-1.61378682j]
#   ...
#   [ 3.28975677-1.55379403j]
#   [ 3.30248475-1.52951789j]
#   [ 3.37394118-1.45149267j]]
#
#  [[ 3.38422251-1.38273036j]
#   [ 3.4385972 -1.50664544j]
#   [ 3.45390534-1.43958414j]
#   ...
#   [ 3.36365414-1.45631278j]
#   [ 3.42402458-1.50505853j]
#   [ 3.34450102-1.44257724j]]
#
#  [[ 3.45248246-1.4448458j ]
#   [ 3.45970869-1.31631351j]
#   [ 3.48091221-1.46810973j]
#   ...
#   [ 3.36104202-1.43031645j]
#   [ 3.39591193-1.26792502j]
#   [ 3.3080349 -1.43792403j]]] ()
# <function close_exdir at 0x000001D12C9FE950> start: 2019-04-24 02:32:35.967561, started/done/total sweeps: 0/30561/30561,
# Measured data:
# 'S-parameter': parameters: Coil #4 voltage (),:[-1.5, 1.5] (61 points) with setter
# Excitation frequency (Hz),:[5000000000.0, 10000000000.0] (501 points) with setter
# Frequency (Hz),:[7407500000.0, 7407500000.0] (1 points) without setter
# data: [[[-1.92671847-3.02924204j]
#   [-1.94752908-3.10255933j]
#   [-1.88720918-3.05454731j]
#   ...
#   [-1.91096711-3.17357016j]
#   [-1.9440974 -3.02941585j]
#   [-1.91559958-3.19610214j]]
#
#  [[-1.84821808-3.10039783j]
#   [-1.89863002-3.08679175j]
#   [-1.96063244-3.18328524j]
#   ...
#   [-1.86641335-3.01139307j]
#   [-1.92513406-3.02500868j]
#   [-1.89330947-3.0425601j ]]
#
#  [[-1.81379282-3.17884707j]
#   [-1.92038   -3.22048306j]
#   [-1.94522536-3.05767059j]
#   ...
#   [-1.90372705-3.15810633j]
#   [-1.75885332-3.1443491j ]
#   [-1.84777224-3.08964586j]]
#
#  ...
#
#  [[ 3.44399977-1.58675337j]
#   [ 3.38243484-1.47860312j]
#   [ 3.32136512-1.61378682j]
#   ...
#   [ 3.28975677-1.55379403j]
#   [ 3.30248475-1.52951789j]
#   [ 3.37394118-1.45149267j]]
#
#  [[ 3.38422251-1.38273036j]
#   [ 3.4385972 -1.50664544j]
#   [ 3.45390534-1.43958414j]
#   ...
#   [ 3.36365414-1.45631278j]
#   [ 3.42402458-1.50505853j]
#   [ 3.34450102-1.44257724j]]
#
#  [[ 3.45248246-1.4448458j ]
#   [ 3.45970869-1.31631351j]
#   [ 3.48091221-1.46810973j]
#   ...
#   [ 3.36104202-1.43031645j]
#   [ 3.39591193-1.26792502j]
#   [ 3.3080349 -1.43792403j]]] ()
# <function save_default_plot at 0x000001D12F111F28> start: 2019-04-24 02:32:35.967561, started/done/total sweeps: 0/30561/30561,
# Measured data:
# 'S-parameter': parameters: Coil #4 voltage (),:[-1.5, 1.5] (61 points) with setter
# Excitation frequency (Hz),:[5000000000.0, 10000000000.0] (501 points) with setter
# Frequency (Hz),:[7407500000.0, 7407500000.0] (1 points) without setter
# data: [[[-1.92671847-3.02924204j]
#   [-1.94752908-3.10255933j]
#   [-1.88720918-3.05454731j]
#   ...
#   [-1.91096711-3.17357016j]
#   [-1.9440974 -3.02941585j]
#   [-1.91559958-3.19610214j]]
#
#  [[-1.84821808-3.10039783j]
#   [-1.89863002-3.08679175j]
#   [-1.96063244-3.18328524j]
#   ...
#   [-1.86641335-3.01139307j]
#   [-1.92513406-3.02500868j]
#   [-1.89330947-3.0425601j ]]
#
#  [[-1.81379282-3.17884707j]
#   [-1.92038   -3.22048306j]
#   [-1.94522536-3.05767059j]
#   ...
#   [-1.90372705-3.15810633j]
#   [-1.75885332-3.1443491j ]
#   [-1.84777224-3.08964586j]]
#
#  ...
#
#  [[ 3.44399977-1.58675337j]
#   [ 3.38243484-1.47860312j]
#   [ 3.32136512-1.61378682j]
#   ...
#   [ 3.28975677-1.55379403j]
#   [ 3.30248475-1.52951789j]
#   [ 3.37394118-1.45149267j]]
#
#  [[ 3.38422251-1.38273036j]
#   [ 3.4385972 -1.50664544j]
#   [ 3.45390534-1.43958414j]
#   ...
#   [ 3.36365414-1.45631278j]
#   [ 3.42402458-1.50505853j]
#   [ 3.34450102-1.44257724j]]
#
#  [[ 3.45248246-1.4448458j ]
#   [ 3.45970869-1.31631351j]
#   [ 3.48091221-1.46810973j]
#   ...
#   [ 3.36104202-1.43031645j]
#   [ 3.39591193-1.26792502j]
#   [ 3.3080349 -1.43792403j]]] (<qsweepy.database.database object at 0x000001D1314CC710>,)
# load_exdir: file open time:  0.002002239227294922
# load_exdir: file open time:  0.0010170936584472656
# load_exdir: file open time:  0.0009980201721191406
# load time:  0.043961524963378906
# pre_trace_time:  0.0009989738464355469
# trace 0 time:  0.030002117156982422
# trace 1 time:  0.057988882064819336
# trace 2 time:  0.0869588851928711
# trace 3 time:  0.11596274375915527
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\memmap.py:335: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
dac.set_voltage(0.8, channel=17)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %%
dac.set_voltage(0.6, channel=17)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %% [markdown]
# # Two tone Yokogava

# %%
if coil_device != current_src1:
    if coil_device ==awg_tek:
        raise ValueError('awg_tek is the active coil control device. This cell is for current_src1 (Yokogawa)')
    if coil_device ==dac:
        raise ValueError('dac is the active coil control device. This cell is for current_src1 (Yokogawa).')

        
#qubit_id='1'
current_max = 4.7e-3 # 7 mA - max on coil
#voltage_max = 1
current_nop = 34
#currents=np.linspace(-current_max,current_max,current_nop)
currents=np.linspace(-0.00035,-2.0e-3,current_nop)
#current_src1.set_status(1)

lo1.set_status(0)
pna.set_power(-50) #-30

freq_nop =7961#161 #961
freqs= np.linspace(0.04e9,8.0e9,freq_nop)
#freqs= np.linspace(5e9,10e9,freq_nop)
pna.set_nop(1)
pna.set_bandwidth(10)
base_power = -10
frequency_gain  = 6.8
lo1.set_power(-10)
lo1.set_status(1)
delay = 70e-9

def sleep(x):
    coil_device.set_current(x)
for qubit_id in ['5']:#['1', '3']:
    
        coil_device.set_status(1)
        coil_device.set_current(0)
        coil = 'DC_coil'
        res_freq = 7.4925e9#qubits[qubit_id]['r']['Fr']
        pna.set_frequency(res_freq)
        pna.set_centerfreq(res_freq)

                   
        def set_corrected_frequency(x):
            lo1.set_frequency(x)
            #lo1.set_power(x/1e9*frequency_gain+base_power)
            
        result = sweeper.sweep(pna,
                                 (currents, lambda x: sleep(x), 'Coil #{} current, qubit{}'.format(coil,qubit_id)),
                                 (freqs,set_corrected_frequency, 'Excitation frequency', 'Hz'),
                                 measurement_type='tone_tone_spectroscopy',
                                 metadata = {'resonator_id': qubit_id,
                                             'probe_power': pna.get_power(),
                                             'base_pump_power': lo1.get_power(),
                                             'frequeny_gain': frequency_gain,
                                             'bw': pna.get_bandwidth(),
                                             'fr': res_freq,
                                             'coil': coil,
                                            })
            
        coil_device.set_current(0)#0)
        coil_device.set_status(0)
        lo1.set_status(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# ...
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-ec47d4b35a2e> in <module>()
#      54                                              'bw': pna.get_bandwidth(),
#      55                                              'fr': res_freq,
# ---> 56                                              'coil': coil,
#      57                                             })
#      58
#
# C:\qtlab_replacement\qsweepy\sweep_extras.py in sweep(self, on_start, on_update, on_finish, *args, **kwargs)
#      64                            on_finish=on_finish+self.on_finish,
#      65                            on_update=on_update+self.on_update,
# ---> 66                            **kwargs)
#      67
#      68     def sweep_fit_dataset_1d_onfly(self, *args, on_start=[], on_update=[], on_finish=[], fitter_arguments=tuple(), **kwargs):
#
# C:\qtlab_replacement\qsweepy\sweep.py in sweep(measurer, shuffle, on_start, on_update, on_finish, use_deferred, ignore_callback_errors, *parameters, **kwargs)
#     213             mpoint = measurer.measure()
#     214             #saving data to containers
# --> 215             set_single_measurement_result(mpoint, indeces)
#     216
#     217         state.measurement_time += time.time() - measurement_start
#
# C:\qtlab_replacement\qsweepy\sweep.py in set_single_measurement_result(single_measurement_result, indeces)
#     174         for event_handler, arguments in on_update:
#     175             try:
# --> 176                 event_handler(state, indeces, *arguments)
#     177             except Exception as e:
#     178                 if not ignore_callback_errors:
#
# C:\qtlab_replacement\qsweepy\ponyfiles\save_exdir.py in update_exdir(state, indeces)
#      74 def update_exdir(state, indeces):
#      75     for dataset in state.datasets.keys():
# ---> 76         state.exdir.attrs.update(state.metadata)
#      77         try:
#      78             state.datasets[dataset].data_exdir[tuple(indeces)] = state.datasets[dataset].data[tuple(indeces)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\exdir\core\attribute.py in update(self, value)
#     213         """
#     214         for key in value:
# --> 215             self[key] = value[key]
#     216
#     217     def __str__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\exdir\core\attribute.py in __setitem__(self, name, value)
#      81         sub_attrs[key] = value
#      82
# ---> 83         self._set_data(attrs)
#      84
#      85     def __contains__(self, name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\exdir\core\attribute.py in _set_data(self, attrs)
#     176                 default_flow_style=False,
#     177                 allow_unicode=True,
# --> 178                 Dumper=yaml.RoundTripDumper
#     179             )
#     180
#
# C:\ProgramData\Anaconda3\lib\site-packages\ruamel_yaml\main.py in dump(data, stream, Dumper, default_style, default_flow_style, canonical, indent, width, allow_unicode, line_break, encoding, explicit_start, explicit_end, version, tags, block_seq_indent)
#     847                     encoding=encoding, explicit_start=explicit_start,
#     848                     explicit_end=explicit_end,
# --> 849                     version=version, tags=tags, block_seq_indent=block_seq_indent)
#     850
#     851
#
# C:\ProgramData\Anaconda3\lib\site-packages\ruamel_yaml\main.py in dump_all(documents, stream, Dumper, default_style, default_flow_style, canonical, indent, width, allow_unicode, line_break, encoding, explicit_start, explicit_end, version, tags, block_seq_indent, top_level_colon_align, prefix_colon)
#     808         for data in documents:
#     809             try:
# --> 810                 dumper._representer.represent(data)
#     811             except AttributeError:
#     812                 # print(dir(dumper._representer))
#
# C:\ProgramData\Anaconda3\lib\site-packages\ruamel_yaml\representer.py in represent(self, data)
#      72         # type: (Any) -> None
#      73         node = self.represent_data(data)
# ---> 74         self.serializer.serialize(node)
#      75         self.represented_objects = {}  # type: Dict[Any, Any]
#      76         self.object_keeper = []  # type: List[Any]
#
# C:\ProgramData\Anaconda3\lib\site-packages\ruamel_yaml\serializer.py in serialize(self, node)
#     103         self.anchor_node(node)
#     104         self.serialize_node(node, None, None)
# --> 105         self.emitter.emit(DocumentEndEvent(explicit=self.use_explicit_end))
#     106         self.serialized_nodes = {}
#     107         self.anchors = {}
#
# C:\ProgramData\Anaconda3\lib\site-packages\ruamel_yaml\emitter.py in emit(self, event)
#     214         while not self.need_more_events():
#     215             self.event = self.events.pop(0)
# --> 216             self.state()
#     217             self.event = None
#     218
#
# C:\ProgramData\Anaconda3\lib\site-packages\ruamel_yaml\emitter.py in expect_document_end(self)
#     347                 self.write_indicator(u'...', True)
#     348                 self.write_indent()
# --> 349             self.flush_stream()
#     350             self.state = self.expect_document_start
#     351         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\ruamel_yaml\emitter.py in flush_stream(self)
#    1032         # type: () -> None
#    1033         if hasattr(self.stream, 'flush'):
# -> 1034             self.stream.flush()
#    1035
#    1036     def write_stream_start(self):
#
# KeyboardInterrupt:

# %%
if coil_device != current_src1:
    if coil_device ==awg_tek:
        raise ValueError('awg_tek is the active coil control device. This cell is for current_src1 (Yokogawa)')
    if coil_device ==dac:
        raise ValueError('dac is the active coil control device. This cell is for current_src1 (Yokogawa).')
#coil = 'z1'

#qubit_id='1'
current_max = 5.5e-3 # 7 mA - max on coil
#voltage_max = 1
current_nop = 551
currents=np.linspace(-current_max,current_max,current_nop)
#voltages=np.linspace(-voltage_max,voltage_max,current_nop)
#current_src1.set_status(1)
pna.set_nop(121)
pna.set_bandwidth(50)
pna.set_power(qubits[qubit_id]['r']['P'])
lo1.set_status(0)

pna.set_power(-55) #-30

def sleep(x):
    coil_device.set_current(x)
    #time.sleep(4)
for qubit_id in ['1']:#,'2','3','4','5','6']: '1','4','5',
        coil_device.set_status(1)
        coil_device.set_current(0)
        coil = 'DC_coil_1'
        #coil = 'Yokogawa-'+qubit_id
        #pna.set_nop((qubits[qubit_id]['r']['Fr_max']-qubits[qubit_id]['r']['Fr_min'])/qubits[qubit_id]['r']['dFr']+1)
        #pna.set_xlim(qubits[qubit_id]['r']['Fr_min'], qubits[qubit_id]['r']['Fr_max'])
        pna.set_xlim(4.9538e9, 4.9544e9)
        result = sweeper.sweep(pna, 
                        (currents, lambda x: sleep(x), 'Coil #{} current, qubit{}'.format(coil,qubit_id)), 
                        #sample_name=sample_name,
                        #sample_name='Fluxonium_1907_063_2',
                        measurement_type='resonator_anticrossing',
                        metadata={'qubit':qubit_id,'coil':coil,'pna_power':pna.get_power(),'sample_name':sample_name})
        coil_device.set_current(0)#0)
        coil_device.set_status(0)
lo1.set_status(0)

# %%
if coil_device != current_src1:
    if coil_device ==awg_tek:
        raise ValueError('awg_tek is the active coil control device. This cell is for current_src1 (Yokogawa)')
    if coil_device ==dac:
        raise ValueError('dac is the active coil control device. This cell is for current_src1 (Yokogawa).')

        
#qubit_id='1'
current_max = 5.5e-3 # 7 mA - max on coil
current_max = 3.3e-3
#voltage_max = 1
current_nop = 44
#currents=np.linspace(-current_max,current_max,current_nop)
currents=np.linspace(-current_max,0.001,current_nop)
#current_src1.set_status(1)

lo1.set_status(0)
pna.set_power(-61) #-30

freq_nop =1401#161 #961
freqs= np.linspace(3.5e9,10.5e9,freq_nop)
#freqs= np.linspace(5e9,10e9,freq_nop)
pna.set_nop(1)
pna.set_bandwidth(10)
base_power = -10
frequency_gain  = 6.8
lo1.set_power(-15)
lo1.set_status(1)
delay = 70e-9

def sleep(x):
    coil_device.set_current(x)
for qubit_id in ['1']:#['1', '3']:
    
        coil_device.set_status(1)
        coil_device.set_current(0)
        coil = 'DC_coil_1'
        res_freq = qubits[qubit_id]['r']['Fr']
        pna.set_frequency(res_freq)
        pna.set_centerfreq(res_freq)

                   
        def set_corrected_frequency(x):
            lo1.set_frequency(x)
            #lo1.set_power(x/1e9*frequency_gain+base_power)
            
        result = sweeper.sweep(pna,
                                 (currents, lambda x: sleep(x), 'Coil #{} current, qubit{}'.format(coil,qubit_id)),
                                 (freqs,set_corrected_frequency, 'Excitation frequency', 'Hz'),
                                 measurement_type='tone_tone_spectroscopy',
                                 metadata = {'resonator_id': qubit_id,
                                             'probe_power': pna.get_power(),
                                             'base_pump_power': lo1.get_power(),
                                             'frequeny_gain': frequency_gain,
                                             'bw': pna.get_bandwidth(),
                                             'fr': res_freq,
                                             'coil': coil,
                                            })
            
        coil_device.set_current(0)#0)
        coil_device.set_status(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# ...
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# load time:  0.04999995231628418
# pre_trace_time:  0.0
# trace 0 time:  0.029975175857543945
# trace 1 time:  0.059992074966430664
# trace 2 time:  0.08998680114746094
# trace 3 time:  0.11998343467712402
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\memmap.py:335: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
awg_tek.set_offset(0.14, channel=3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# True

# %% [markdown]
# ### two-tone power skan

# %%
nndac_channel_id=21
#voltages = np.linspace(-4, 4, 201)
voltages = [0]

# %%
#voltage_max = 4
#voltage_nop = 51
freq_nop = 1001
#nndac_channels = [6,8,10]#[0,2,4]

#voltages=np.linspace(-.5,.5,voltage_nop)
#voltages=np.linspace(-voltage_max,voltage_max,voltage_nop)
freqs= np.linspace(4.0e9,7.0e9,freq_nop)
pna.set_nop(1)
pna.set_bandwidth(20)
pna.set_power(-35)
lo1.set_power(10)
lo1.set_status(1)
delay = 70e-9
for qubit_id in ['1','3']:#, '2', '3']:
    #for coil_control_channel in [qubits[qubit_id]['q']['P']['nndac_coil_id']]:
#for nndac_channel_id in nndac_channels:
#    for qubit_id in ['1', '2', '3']:
        pna.set_power(qubits[qubit_id]['r']['P']-0)
        try: 
            coil = 'NNDAC-'+str(nndac_channel_id)
            #dac.set_voltage(0, channel=0)
            #dac.set_voltage(0, channel=2)
            #dac.set_voltage(0, channel=4)
            #dac.set_voltage(qubits[qubit_id]['q']['P']['Fmin_coil_currents'][6], channel=6)
            #dac.set_voltage(qubits[qubit_id]['q']['P']['Fmin_coil_currents'][8], channel=8)
            #dac.set_voltage(qubits[qubit_id]['q']['P']['Fmin_coil_currents'][10], channel=10)
            def set_volt_res(x):
                dac.set_voltage(x, channel=nndac_channel_id)
                #res_freq = find_resonator(qubit_id, criterion='max_dev_complex', delay=delay,
                #                          check=1, raise_on_error=False)
                #pna.set_frequency(res_freq)
                #pna.set_centerfreq(res_freq)
            result = sweep.sweep(pna,
                                 (voltages, 
                                  set_volt_res, 'Coil #{} voltage, qubit{}'.format(coil,qubit_id)),
                                 (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
                                 sample_name = sample_name,
                                 measurement_type='two-tone spectroscopy',
                                 type_revision='0',
                                 metadata = {'fr':})
                                 #filename='Sample 1902_165-2 Coil #{} two-tone qubit{}'.format(coil,qubit_id))
            dac.set_voltage(0,nndac_channel_id)
        except KeyboardInterrupt:
            for nndac_channel in nndac_channels:
                dac.set_voltage(0,nndac_channel)
            raise
        finally:
            for nndac_channel in nndac_channels:
                dac.set_voltage(0,nndac_channel)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# HTML(value='')
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# Started at:  Mar 20 2019 03:36:53
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:1402: RuntimeWarning: invalid value encountered in remainder
#   ddmod = mod(dd + pi, 2*pi) - pi
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:1403: RuntimeWarning: invalid value encountered in greater
#   _nx.copyto(ddmod, pi, where=(ddmod == -pi) & (dd > 0))
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:1405: RuntimeWarning: invalid value encountered in less
#   _nx.copyto(ph_correct, 0, where=abs(dd) < discont)
# resonator found at 7085500000.0
# C:\qtlab_replacement\qsweepy\sweep.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data[mname][[(i) for i in indeces]+[...]] = mpoint_m
# Exiting sweep main thread #{} via return 11424
#
# Elapsed time: 0 h 1 m 18.63 s
# HTML(value='')
# Started at:  Mar 20 2019 03:38:14
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:1402: RuntimeWarning: invalid value encountered in remainder
#   ddmod = mod(dd + pi, 2*pi) - pi
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:1403: RuntimeWarning: invalid value encountered in greater
#   _nx.copyto(ddmod, pi, where=(ddmod == -pi) & (dd > 0))
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:1405: RuntimeWarning: invalid value encountered in less
#   _nx.copyto(ph_correct, 0, where=abs(dd) < discont)
# resonator found at 7376900000.0
# C:\qtlab_replacement\qsweepy\sweep.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data[mname][[(i) for i in indeces]+[...]] = mpoint_m
# Exiting sweep main thread #{} via return 2304
#
# Elapsed time: 0 h 1 m 19.0 s

# %% [markdown]
# ### Working two-tone

# %%
voltages = np.linspace(-0.05, 0.05, 51)
freqs= np.linspace(4.75e9,5.25e9,101)
pna.set_nop(1)
pna.set_bandwidth(50)
pna.set_power(-45)
lo1.set_power(18)
lo1.set_status(1)
delay = 71e-9
for qubit_id in ['2']:
        #dac.set_voltage(-4, channel=22)
        def set_volt_res(x):
            dac.set_voltage(x, channel=21)
            res_freq = find_resonator(qubit_id, criterion='max_dev_complex', delay=delay,
                                          check=1, raise_on_error=False)
            pna.set_frequency(res_freq)
            pna.set_centerfreq(res_freq)
        result = sweep.sweep(pna,(voltages, set_volt_res, 'Coil voltage'),
                             (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
                                 filename='Sample 1902_165-2 fine #{} two-tone qubit {}'.format(coil,qubit_id))
        dac.set_voltage(0,23)
        dac.set_voltage(0,22)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# HTML(value='')
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# Started at:  Mar 20 2019 06:04:39
# resonator found at 7881600000.0
# C:\qtlab_replacement\qsweepy\sweep.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data[mname][[(i) for i in indeces]+[...]] = mpoint_m
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# resonator found at 7881500000.0
# resonator found at 7881600000.0
# resonator found at 7881500000.0
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# resonator found at 7881400000.0
# resonator found at 7881500000.0
# resonator found at 7881400000.0
# resonator found at 7881500000.0
# resonator found at 7881500000.0
# resonator found at 7881400000.0
# resonator found at 7881500000.0
# resonator found at 7881500000.0
# resonator found at 7881500000.0
# resonator found at 7881500000.0
# resonator found at 7881500000.0
# resonator found at 7881400000.0
# resonator found at 7881400000.0
# resonator found at 7881500000.0
# resonator found at 7881500000.0
# resonator found at 7881500000.0
# resonator found at 7881400000.0
# resonator found at 7881500000.0
# resonator found at 7881400000.0
# resonator found at 7881500000.0
# resonator found at 7881400000.0
# resonator found at 7881400000.0
# resonator found at 7881400000.0
# resonator found at 7881500000.0
# resonator found at 7881600000.0
# resonator found at 7881400000.0
# resonator found at 7881500000.0
# resonator found at 7881600000.0
# resonator found at 7881400000.0
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# resonator found at 7881400000.0
# resonator found at 7881500000.0
# resonator found at 7881600000.0
# resonator found at 7881600000.0
# Exiting sweep main thread #{} via return 7936
#
# Elapsed time: 0 h 6 m 53.05 s

# %%
qubit_id='2'

# %%
qubit_id='1'

# %%
qubits[qubit_id]['q']['P']['Fmin_coil_currents'][1]
# Out:
# 0.4724919

# %%
qubits[qubit_id]['q']['P']['nndac_coil_id']
# Out:
# 6

# %%
qubits[qubit_id]['q']['P']['Fmin_coil_currents']
# Out:
# {1: 0.4724919, 2: -0.60931336, 3: -0.59793759}

# %%
qubit_id='3'
nndac_channel_id=qubits[qubit_id]['q']['P']['nndac_coil_id']


freqs = np.arange(5.7e9, 6.2e9, 2e6)
powers = np.arange(0, 19, 1)

pna.set_nop(1)
# pna.set_xlim(Qubits[qubit_id]['r']['Fr'], Qubits[qubit_id]['r']['Fr'])
pna.set_bandwidth(25)
pna.set_power(-40)
delay = 70e-9
dac.set_voltage(0, channel=0)
#dac.set_voltage(-2.57, channel=1)

def set_volt_res():
    #for _qubit_id in ['1']:
        #for coil_channel_id, channel_voltage in qubits[_qubit_id]['q']['P']['Fmin_coil_currents'].items():
            #dac.set_voltage(channel_voltage, channel=nndac_channel_id)
            #coil_device.set_offset(channel_voltage, channel=coil_channel_id)
    res_freq = find_resonator(qubit_id, criterion='max_dev_complex', delay=delay,
                                  check=3, raise_on_error=False)
    print(res_freq)
    pna.set_frequency(res_freq)
    pna.set_centerfreq(res_freq)
#set_volt_res()
res_freq = qubits[qubit_id]['r']['Fr']
pna.set_frequency(res_freq)
pna.set_centerfreq(res_freq)
lo1.set_status(1)
lo1.set_power(4)
result = sweep.sweep(pna,
                     (powers,lo1.set_power,'two-tone power','dB'),
                     (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
                     filename='Sample 1902-164-1 Coil #{} two-tone qubit{}'.format(1,qubit_id))

# lo1.set_status(1)
# #ps.S21vs2DPar(pna, currents, current.set_current, ex_freqs, lo1.set_frequency, filename = "#2{:.1f}dBm".format(lo1.get_power()),\
# #           header = header)
# ex2D = sweep.sweep(pna, (ex_powers, lo1.set_power, 'Мощность второго тона, дБ'), 
#                    (ex_freqs, lo1.set_frequency, 'Частота второго тона, ГГц'), 
#                    filename = "Двухтоновая спектроскопия при различных мощностях второго (возбуждающего) тона образец #{}".format(qubit_id),\
#            header = header, shuffle=True)
# lo1.set_status(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# HTML(value='')
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# Started at:  Mar 19 2019 11:20:51
# C:\qtlab_replacement\qsweepy\sweep.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data[mname][[(i) for i in indeces]+[...]] = mpoint_m
# Exiting sweep main thread #{} via return 7924
#
# Elapsed time: 0 h 4 m 46.77 s

# %% [markdown]
# ### Working powerskan

# %%
qubit_id='1'

# %%
np.arange(14, 19, 2)
# Out:
# array([14, 16, 18])

# %%
## qubit_id='1'
#nndac_channel_id=qubits[qubit_id]['q']['P']['nndac_coil_id']

qubit_id='1'
freqs = np.arange(6.6e9, 7.05e9,1e6)
powers = np.arange(-5, 10.0, 1)
#powers =[5]
pna.set_nop(1)
# pna.set_xlim(Qubits[qubit_id]['r']['Fr'], Qubits[qubit_id]['r']['Fr'])
pna.set_bandwidth(50)
pna.set_power(-35)
delay = 70e-9
dac.set_voltage(-0.98, channel=21)
#dac.set_voltage(-2.57, channel=1)

def set_volt_res():
    #for _qubit_id in ['1']:
        #for coil_channel_id, channel_voltage in qubits[_qubit_id]['q']['P']['Fmin_coil_currents'].items():
            #dac.set_voltage(channel_voltage, channel=nndac_channel_id)
            #coil_device.set_offset(channel_voltage, channel=coil_channel_id)
    res_freq = find_resonator(qubit_id, criterion='max_dev_complex', delay=delay,
                                  check=3, raise_on_error=False)
    print(res_freq)
    pna.set_frequency(res_freq)
    pna.set_centerfreq(res_freq)
#set_volt_res()
res_freq = qubits[qubit_id]['r']['Fr']
pna.set_frequency(res_freq)
pna.set_centerfreq(res_freq)
lo1.set_status(1)
lo1.set_power(10)
result = sweep.sweep(pna,
                     (powers,lo1.set_power,'two-tone power','dB'),
                     (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
                     filename='Sample 1902-165-02 1d Uncoupled Coil #{} two-tone qubit{}'.format(1,qubit_id))

# lo1.set_status(1)
# #ps.S21vs2DPar(pna, currents, current.set_current, ex_freqs, lo1.set_frequency, filename = "#2{:.1f}dBm".format(lo1.get_power()),\
# #           header = header)
# ex2D = sweep.sweep(pna, (ex_powers, lo1.set_power, 'Мощность второго тона, дБ'), 
#                    (ex_freqs, lo1.set_frequency, 'Частота второго тона, ГГц'), 
#                    filename = "Двухтоновая спектроскопия при различных мощностях второго (возбуждающего) тона образец #{}".format(qubit_id),\
#            header = header, shuffle=True)
# lo1.set_status(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# HTML(value='')
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# Started at:  Mar 20 2019 06:41:07
# C:\qtlab_replacement\qsweepy\sweep.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data[mname][[(i) for i in indeces]+[...]] = mpoint_m
# Exiting sweep main thread #{} via return 11580
#
# Elapsed time: 0 h 5 m 30.6 s

# %% [markdown]
# # Inductance matrix

# %%
import qsweepy.save_pkl

# %% [markdown]
# ## visualization of anticrossing

# %%
# plot all anitcrossings on one axes
figs, axes = plt.subplots(3,3, figsize=(12,9))
locations = [[r'D:\data\2018-09-19\17-35-56-Sample 1 Coil #NNDAC-0 anticrossings qubit 1', 
              r'D:\data\2018-09-19\17-38-23-Sample 1 Coil #NNDAC-0 anticrossings qubit 2',
              r'D:\data\2018-09-19\17-43-49-Sample 1 Coil #NNDAC-0 anticrossings qubit 3'],
            [r'D:\data\2018-09-19\17-48-29-Sample 1 Coil #NNDAC-2 anticrossings qubit 1',
             r'D:\data\2018-09-19\17-50-56-Sample 1 Coil #NNDAC-2 anticrossings qubit 2',
             r'D:\data\2018-09-19\17-56-23-Sample 1 Coil #NNDAC-2 anticrossings qubit 3'],
            [r'D:\data\2018-09-19\18-01-03-Sample 1 Coil #NNDAC-4 anticrossings qubit 1',
             r'D:\data\2018-09-19\18-03-30-Sample 1 Coil #NNDAC-4 anticrossings qubit 2',
             r'D:\data\2018-09-19\18-08-56-Sample 1 Coil #NNDAC-4 anticrossings qubit 3']]
locations = [[r'D:\data\2018-09-25\10-00-51-1808_072-2 Coil #NNDAC-18 anticrossings qubit 1',
             r'D:\data\2018-09-25\10-03-28-1808_072-2 Coil #NNDAC-18 anticrossings qubit 2',
             r'D:\data\2018-09-25\10-07-19-1808_072-2 Coil #NNDAC-18 anticrossings qubit 3'],
             [r'D:\data\2018-09-25\10-09-55-1808_072-2 Coil #NNDAC-20 anticrossings qubit 1', 
              r'D:\data\2018-09-25\10-12-35-1808_072-2 Coil #NNDAC-20 anticrossings qubit 2',
              r'D:\data\2018-09-25\10-16-25-1808_072-2 Coil #NNDAC-20 anticrossings qubit 3'],
            [r'D:\data\2018-09-25\10-19-05-1808_072-2 Coil #NNDAC-16 anticrossings qubit 1',
             r'D:\data\2018-09-25\10-21-43-1808_072-2 Coil #NNDAC-16 anticrossings qubit 2',
             r'D:\data\2018-09-25\10-25-33-1808_072-2 Coil #NNDAC-16 anticrossings qubit 3']]
#files = [['Sample 1 Coil #NNDAC-{0} anticrossings qubit {1}'.format(i,j) for j in ['1', '2', '3'] ] for i in [0,2,4]]
files = [['1808_072-2 Coil #NNDAC-{0} anticrossings qubit {1}'.format(i,j) for j in ['1', '2', '3']]
        for i in [18, 20, 16]]
delays = []
for row_id in range(len(locations)):
    for column_id in range(len(locations[0])):
        data = qsweepy.save_pkl.load_pkl(files[row_id][column_id],locations[row_id][column_id])[1]['S-parameter']
        unwrapped = np.unwrap(np.angle(data[2])).T
        delays.append((unwrapped[-1,:]-unwrapped[0,:]+2*np.pi)/(data[1][1][-1]-data[1][1][0]))
        print (np.median((unwrapped[-1,:]-unwrapped[0,:]+2*np.pi)))
delay = np.median(delays)

anticrossing_matrix = []

for row_id in range(len(locations)):
    anticrossing_row = []
    for column_id in range(len(locations[0])):
        data = qsweepy.save_pkl.load_pkl(files[row_id][column_id],locations[row_id][column_id])[1]['S-parameter']
        #unwrapped = np.unwrap(np.angle(data[2])).T
        #phase_diff = unwrapped[-1,:]-unwrapped[0,:]
        #data_nodelay = (data[2]*np.exp(-1j*np.linspace(0,np.median(phase_diff),unwrapped.shape[0]))).T
        data_nodelay = (data[2]*np.exp(-1j*delay*data[1][1])).T
        data_deviation_complex = data_nodelay - np.mean(data_nodelay, axis=0)
        anticrossing_row.append(data_deviation_complex)
        #axes[row_id,column_id].pcolormesh(data[1][0], data[1][1], np.angle(data_nodelay), cmap='RdBu')
        im = axes[row_id,column_id].pcolormesh(data[1][0], data[1][1], np.abs(data_deviation_complex), cmap='RdBu_r')
# D:\data\2018-09-25\10-21-43-1808_072-2 Coil #NNDAC-16 anticrossings qubit 2/1808_072-2 Coil #NNDAC-16 anticrossings qubit 2.pkl
# D:\data\2018-09-25\10-25-33-1808_072-2 Coil #NNDAC-16 anticrossings qubit 3/1808_072-2 Coil #NNDAC-16 anticrossings qubit 3.pkl
# -4.24859502251e-08

# %%
plt.figure()
centre_pix, period_pix = fitting.xcorr_centre_period(anticrossing_matrix[1][1], axis=1, drop_size=0)

#centre_par = resonator_reference_spectrum['S-parameter'][1][0][int(centre_reference_pixels)], 
#period_par = (resonator_reference_spectrum['S-parameter'][1][0][1]-resonator_reference_spectrum['S-parameter'][1][0][0])*period_reference_pixels
print (centre_pix, period_pix)
len(data[1][0]), data[1][0]
# Out:
# 42.5883575884 1
# (201, array([-4.  , -3.96, -3.92, -3.88, -3.84, -3.8 , -3.76, -3.72, -3.68,
#         -3.64, -3.6 , -3.56, -3.52, -3.48, -3.44, -3.4 , -3.36, -3.32,
#         -3.28, -3.24, -3.2 , -3.16, -3.12, -3.08, -3.04, -3.  , -2.96,
#         -2.92, -2.88, -2.84, -2.8 , -2.76, -2.72, -2.68, -2.64, -2.6 ,
#         -2.56, -2.52, -2.48, -2.44, -2.4 , -2.36, -2.32, -2.28, -2.24,
#         -2.2 , -2.16, -2.12, -2.08, -2.04, -2.  , -1.96, -1.92, -1.88,
#         -1.84, -1.8 , -1.76, -1.72, -1.68, -1.64, -1.6 , -1.56, -1.52,
#         -1.48, -1.44, -1.4 , -1.36, -1.32, -1.28, -1.24, -1.2 , -1.16,
#         -1.12, -1.08, -1.04, -1.  , -0.96, -0.92, -0.88, -0.84, -0.8 ,
#         -0.76, -0.72, -0.68, -0.64, -0.6 , -0.56, -0.52, -0.48, -0.44,
#         -0.4 , -0.36, -0.32, -0.28, -0.24, -0.2 , -0.16, -0.12, -0.08,
#         -0.04,  0.  ,  0.04,  0.08,  0.12,  0.16,  0.2 ,  0.24,  0.28,
#          0.32,  0.36,  0.4 ,  0.44,  0.48,  0.52,  0.56,  0.6 ,  0.64,
#          0.68,  0.72,  0.76,  0.8 ,  0.84,  0.88,  0.92,  0.96,  1.  ,
#          1.04,  1.08,  1.12,  1.16,  1.2 ,  1.24,  1.28,  1.32,  1.36,
#          1.4 ,  1.44,  1.48,  1.52,  1.56,  1.6 ,  1.64,  1.68,  1.72,
#          1.76,  1.8 ,  1.84,  1.88,  1.92,  1.96,  2.  ,  2.04,  2.08,
#          2.12,  2.16,  2.2 ,  2.24,  2.28,  2.32,  2.36,  2.4 ,  2.44,
#          2.48,  2.52,  2.56,  2.6 ,  2.64,  2.68,  2.72,  2.76,  2.8 ,
#          2.84,  2.88,  2.92,  2.96,  3.  ,  3.04,  3.08,  3.12,  3.16,
#          3.2 ,  3.24,  3.28,  3.32,  3.36,  3.4 ,  3.44,  3.48,  3.52,
#          3.56,  3.6 ,  3.64,  3.68,  3.72,  3.76,  3.8 ,  3.84,  3.88,
#          3.92,  3.96,  4.  ]))

# %%
anticrossing_matrix[0][0].shape
# Out:
# (81, 201)

# %% [markdown]
# # Nice Q1-Q2 anticrossing for demonstration

# %% [markdown]
# ## Qubit-resonator anticrossings at non-zero bias on second control

# %%
#coil = 'z1'
#current_max = 1.5e-3
voltage_max = 4
current_nop = 101
nndac_channels = [2]#[21,1,7]
#currents=np.linspace(-current_max,current_max,current_nop)
voltages=np.linspace(-voltage_max,voltage_max,current_nop)
#current_src1.set_status(1)
pna.set_nop(501)
pna.set_bandwidth(500)
pna.set_power(qubits[qubit_id]['r']['P']+25) 
coil2_voltage = 1.5
for nndac_channel_id in nndac_channels:
    for qubit_id in ['1', '2', '3']:
        dac.set_voltage(coil2_voltage, channel=0)
        coil = 'NNDAC-'+str(nndac_channel_id)
        #pna.set_xlim(qubits[qubit_id]['r']['Fr']-50e6,qubits[qubit_id]['r']['Fr']+50e6)
        pna.set_nop((qubits[qubit_id]['r']['Fr_max']-qubits[qubit_id]['r']['Fr_min'])/qubits[qubit_id]['r']['dFr']+1)
        pna.set_xlim(qubits[qubit_id]['r']['Fr_min'], qubits[qubit_id]['r']['Fr_max'])
        result = sweep.sweep(pna, 
                        (voltages, lambda x: dac.set_voltage(x, channel=nndac_channel_id), 'Coil #{} voltage, qubit{}'.format(coil,qubit_id)), 
                        filename='Ch1-1-Ch2-2 Coil #{} anticrossings qubit {}'.format(coil, qubit_id))
        dac.set_voltage(0, channel=nndac_channel_id)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# HTML(value='')
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# Started at:  Mar 02 2019 11:47:31
# C:\qtlab_replacement\qsweepy\sweep.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data[mname][[(i) for i in indeces]+[...]] = mpoint_m
# Exiting sweep main thread #{} via return 9832
#
# Elapsed time: 0 h 0 m 24.57 s
# HTML(value='')
# Started at:  Mar 02 2019 11:47:59
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# C:\qtlab_replacement\qsweepy\sweep.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data[mname][[(i) for i in indeces]+[...]] = mpoint_m
# Exiting sweep main thread #{} via return 2380
#
# Elapsed time: 0 h 1 m 46.47 s
# HTML(value='')
# Started at:  Mar 02 2019 11:49:48
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# C:\qtlab_replacement\qsweepy\sweep.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data[mname][[(i) for i in indeces]+[...]] = mpoint_m
# Exiting sweep main thread #{} via return 13788
#
# Elapsed time: 0 h 0 m 24.6 s

# %% [markdown]
# ## Qubit-resonator anticrossing at abstract control parameter for high-quality anticrossing picture

# %%
#coil = 'z1'
#current_max = 1.5e-3
voltage_max = 2.5
current_nop = 101
nndac_channels = [2]#[21,1,7]
#currents=np.linspace(-current_max,current_max,current_nop)
voltages=np.linspace(-voltage_max,voltage_max,current_nop)
#current_src1.set_status(1)
pna.set_nop(501)
pna.set_bandwidth(500)
pna.set_power(qubits[qubit_id]['r']['P']) 
coil2_voltage = 1.5
for nndac_channel_id in nndac_channels:
    for qubit_id in ['2']:
        dac.set_voltage(coil2_voltage, channel=0)
        coil = 'NNDAC-'+str(nndac_channel_id)
        #pna.set_xlim(qubits[qubit_id]['r']['Fr']-50e6,qubits[qubit_id]['r']['Fr']+50e6)
        pna.set_nop((qubits[qubit_id]['r']['Fr_max']-qubits[qubit_id]['r']['Fr_min'])/qubits[qubit_id]['r']['dFr']+1)
        pna.set_xlim(qubits[qubit_id]['r']['Fr_min'], qubits[qubit_id]['r']['Fr_max'])
        def set_sweep_parameter(V):
            dac.set_voltage(1.5-V, channel=0)
            dac.set_voltage(1.5+V, channel=2)
        result = sweep.sweep(pna, 
                        (voltages, set_sweep_parameter, 'Abstract voltage-like sweep parameter'.format(coil,qubit_id)), 
                        filename='1809-001_2 Coil #{} anticrossings qubit {}'.format(coil, qubit_id))
        dac.set_voltage(0, channel=nndac_channel_id)
# Out:
# A Jupyter Widget
# Started at:  Sep 20 2018 12:16:13
# Exiting sweep main thread #{} via return 11612
#
# Elapsed time: 0 h 4 m 11.24 s

# %% [markdown]
# ## Qubit-qubit anticrossing vs abstract control parameter

# %%
#L_mat=np.asarray([[ 0.31045445, -0.06621955, -0.02083502],
#        [ 0.08090813,  0.29212717, -0.13412727],
#        [-0.07698924,  0.06840561,  0.13873278]])

#phi0_vec = [-0.029960100879772234, -0.025342234038425226, -0.038382257248394662]


#L_mat = np.asarray([[ 2.432, -0.476,  -0.144], [ 0.583 ,  2.178, -1.084], [-0.689,  0.473,  0.989  ]])
#phi0_vec = np.asarray([-0.002, -0.004, 0.002])
np.asarray(L_mat), phi0_vec
# Out:
# (array([[ 2.4316565 , -0.47950326, -0.14150814],
#         [ 0.53928393,  2.17353468, -1.09987528],
#         [-1.23003529,  0.49316206,  0.96886678]]),
#  array([-0.00099724, -0.00110277, -0.00267987]))

# %%
awg_tek.stop()
for i in range(1,5):
    awg_tek.set_output(0, channel=i)
    #awg_tek.set_waveform([0]*50000, channel=i)
    #awg_tek.set_output(1, channel=i)
#awg_tek.run()

# %%
coil_device.set_offset(0.2, channel=1)
#coil_device.run()
# Out:
# True

# %%
awg_tek.run()

# %%
awg_tek.set

# %%
awg_tek.set_output(1, channel=1)
# Out:
# True

# %%
awg_tek.run()

# %%
coil_device.stop()

# %%
voltage_max = 4
voltage_nop = 51
freq_nop = 401
nndac_channels = [6]
fluxes=np.linspace(0.5,0,voltage_nop)
#voltages=np.linspace(-voltage_max,voltage_max,voltage_nop)
freqs= np.linspace(4.85e9,6.05e9,freq_nop)
pna.set_nop(1)
pna.set_bandwidth(50)
lo1.set_power(15)
pna.set_power(-20)
lo1.set_status(1)
delay = 70e-9
for nndac_channel_id in nndac_channels:
    for qubit_id in ['1']:
        #for nndac_channel in [1,2,3]:
        #    dac.set_voltage(0,nndac_channel)
        #pna.set_power(qubits[qubit_id]['r']['P'])
        #try: 
        awg_tek.stop()
        coil_device.set_output(1, channel=1)
        coil_device.set_output(1, channel=2)
        coil_device.set_output(1, channel=3)
        awg_tek.run()
        coil = 'NNDAC-'+str(nndac_channel_id)
        def set_flux_12(x):
            fluxes = [x, 0, -x]
            voltages = np.linalg.solve(np.asarray(L_mat), -np.asarray(phi0_vec)+fluxes)
            coil_device.set_offset(voltages[0], channel=1)
            coil_device.set_offset(voltages[1], channel=2)
            coil_device.set_offset(voltages[2], channel=3)
            print (voltages)

                #dac.set_voltage(1.7-V, channel=6)
                #dac.set_voltage(0.5+V, channel=8)
                #dac.set_voltage(x, channel=nndac_channel_id)
            res_freq = find_resonator(qubit_id, criterion='max_dev_complex', delay=delay, check=3, raise_on_error=False)
            pna.set_frequency(res_freq)
            pna.set_centerfreq(res_freq)
        result = sweep.sweep(pna,
                                 (fluxes, set_flux_12, 'Flux'.format(coil,qubit_id)),
                                 (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
                                 filename=sample_name+' Coil #{} two-tone qubit{}'.format(coil,qubit_id))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# HTML(value='')
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# Started at:  Dec 01 2018 13:56:43
# [ 0.4724919  -0.60931336 -0.59793759]
# Could not find resonator
# C:\qtlab_replacement\qsweepy\sweep.py:218: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data[mname][[(i) for i in indeces]+[...]] = mpoint_m
# [ 0.46303836 -0.59717257 -0.58591836]
# resonator found at 6602740000.0
# [ 0.45358482 -0.58503179 -0.57389913]
# Could not find resonator
# [ 0.44413128 -0.572891   -0.5618799 ]
# Could not find resonator
# [ 0.43467774 -0.56075021 -0.54986066]
# Could not find resonator
# [ 0.4252242  -0.54860942 -0.53784143]
# Could not find resonator
# [ 0.41577066 -0.53646863 -0.5258222 ]
# Could not find resonator
# [ 0.40631712 -0.52432785 -0.51380297]
# resonator found at 6602780000.0
# [ 0.39686358 -0.51218706 -0.50178374]
# resonator found at 6602825000.0
# [ 0.38741004 -0.50004627 -0.48976451]
# Could not find resonator
# [ 0.3779565  -0.48790548 -0.47774527]
# resonator found at 6602915000.0
# [ 0.36850295 -0.4757647  -0.46572604]
# resonator found at 6602895000.0
# [ 0.35904941 -0.46362391 -0.45370681]
# Could not find resonator
# [ 0.34959587 -0.45148312 -0.44168758]
# Could not find resonator
# [ 0.34014233 -0.43934233 -0.42966835]
# Could not find resonator
# [ 0.33068879 -0.42720154 -0.41764912]
# Could not find resonator
# [ 0.32123525 -0.41506076 -0.40562988]
# Could not find resonator
# [ 0.31178171 -0.40291997 -0.39361065]
# resonator found at 6602795000.0
# [ 0.30232817 -0.39077918 -0.38159142]
# resonator found at 6602755000.0
# [ 0.29287463 -0.37863839 -0.36957219]
# Could not find resonator
# [ 0.28342109 -0.36649761 -0.35755296]
# resonator found at 6602625000.0
# [ 0.27396755 -0.35435682 -0.34553373]
# resonator found at 6602875000.0
# [ 0.26451401 -0.34221603 -0.33351449]
# resonator found at 6602860000.0
# [ 0.25506047 -0.33007524 -0.32149526]
# Could not find resonator
# [ 0.24560693 -0.31793445 -0.30947603]
# resonator found at 6602750000.0
# [ 0.23615339 -0.30579367 -0.2974568 ]
# resonator found at 6602940000.0
# [ 0.22669985 -0.29365288 -0.28543757]
# resonator found at 6602785000.0
# [ 0.21724631 -0.28151209 -0.27341834]
# resonator found at 6602770000.0
# [ 0.20779277 -0.2693713  -0.2613991 ]
# resonator found at 6602855000.0
# [ 0.19833923 -0.25723051 -0.24937987]
# resonator found at 6602895000.0
# Exception in thread Thread-23:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\qtlab_replacement\qsweepy\sweep.py", line 282, in main_sweep_loop
#     set_single_measurement_result(mpoint, indeces)
#   File "C:\qtlab_replacement\qsweepy\sweep.py", line 226, in set_single_measurement_result
#     ascii_file.write(data_to_str(fmt(mpoint_m_flat))+'\n')
# ValueError: I/O operation on closed file.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\qtlab_replacement\qsweepy\sweep.py in sweep(measurer, filename, root_dir, plot, plot_separate_thread, header, output, save, time_war_label, shuffle, bot, use_deferred, loc, *params)
#     333                         acq_thread.start()
# --> 334                         plot_thread()
#     335
#
# C:\qtlab_replacement\qsweepy\sweep.py in plot_thread()
#     326                                         #print(plot_thread_point_id, done_sweeps)
# --> 327                                         plt.gcf().canvas.start_event_loop(2.0)
#     328                                 #for i in range(100):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_qt5.py in start_event_loop(self, timeout)
#     482             timer = QtCore.QTimer.singleShot(timeout * 1000, event_loop.quit)
# --> 483         event_loop.exec_()
#     484
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-7f4df2c0efa3> in <module>()
#      41                                  (fluxes, set_flux_12, 'Flux'.format(coil,qubit_id)),
#      42                                  (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
# ---> 43                                  filename=sample_name+' Coil #{} two-tone qubit{}'.format(coil,qubit_id))
#
# C:\qtlab_replacement\qsweepy\sweep.py in sweep(measurer, filename, root_dir, plot, plot_separate_thread, header, output, save, time_war_label, shuffle, bot, use_deferred, loc, *params)
#     357                 header = {'name': filename}
#     358                 if (save):
# --> 359                         filename_location = save_pkl.save_pkl(header, mk_measurement(), location = data_dir, plot_axes=plot_axes)
#     360                 if bot[0]==True:
#     361                         with open(data_dir+"/send_result.txt",'w') as bot_send_file:
#
# C:\qtlab_replacement\qsweepy\save_pkl.py in save_pkl(header, data, plot, curve_fit, annotation, location, time, filename, matlab, gzip, plot_axes)
#      68
#      69         if plot_axes and plot:
# ---> 70                 plotting.update_plot_measurement(data, plot_axes)
#      71                 plotting.plot_add_annotation(plot_axes, annotation)
#      72                 plotting.plot_save(plot_axes, location)
#
# C:\qtlab_replacement\qsweepy\plotting.py in update_plot_measurement(measurement, axes)
#     249                 for plot_name, plot in ax['plots'].items():
#     250                         meas[plot_name] = (measurement[plot['mname']][0], measurement[plot['mname']][1], plot['filter'](measurement[plot['mname']][2]))
# --> 251                 plots = update_plot_measurement_sa(meas, ax)
#     252
#     253         plt.draw()
#
# C:\qtlab_replacement\qsweepy\plotting.py in update_plot_measurement_sa(measurement, plots)
#     368                         plot.set_data(data)
#     369                         plot.set_clim(np.nanmin(data), np.nanmax(data))
# --> 370                 plt.gcf().canvas.start_event_loop(1.0)
#     371
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_qt5.py in start_event_loop(self, timeout)
#     481         if timeout:
#     482             timer = QtCore.QTimer.singleShot(timeout * 1000, event_loop.quit)
# --> 483         event_loop.exec_()
#     484
#     485     def stop_event_loop(self, event=None):
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# %%
voltage_max = 4
voltage_nop = 101
freq_nop = 101
#nndac_channels = [6]
fluxes=np.linspace(-0.75,0.25,voltage_nop)
#voltages=np.linspace(-voltage_max,voltage_max,voltage_nop)
freqs= np.linspace(4.75e9,5.95e9,freq_nop)
pna.set_nop(1)
pna.set_bandwidth(50)
lo1.set_power(-20)
pna.set_power(-50)
lo1.set_status(1)
delay = 50e-9
#for nndac_channel_id in nndac_channels:
for qubit_id, qubit_name in enumerate(['1', '2', '3']):
    try: 
        for coil_control_channel  in coil_control_channels:
            coil_device.set_output(1, channel=coil_control_channel)
        def set_qubit_flux(x):
            fluxes = [0 ,0, 0]
            fluxes[qubit_id] = x
            voltages = np.linalg.solve(np.asarray(L_mat), -np.asarray(phi0_vec)+fluxes)
            for channel_id, channel_voltage in enumerate(voltages):
                coil_device.set_offset(voltages[channel_id], channel=coil_control_channels[channel_id])
            res_freq = find_resonator(qubit_name, criterion='max_dev_complex', delay=delay, check=1, raise_on_error=False)
            pna.set_frequency(res_freq)
            pna.set_centerfreq(res_freq)
        result = sweep.sweep(pna,
                                 (fluxes, set_qubit_flux, 'Qubit {} SQUID flux'.format(qubit_name), 'Phi_0'),
                                 (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
                                 filename=sample_name+' two-tone qubit{}'.format(qubit_name))
    finally:
        for coil_control_channel  in coil_control_channels:
            coil_device.set_offset(0, channel=coil_control_channel)
            coil_device.set_output(0, channel=coil_control_channel)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# HTML(value='')
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# Started at:  Dec 01 2018 12:35:18
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:176: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('Tight layout not applied. The left and right margins '
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-9292471b2a2a> in <module>()
#      29                                  (fluxes, set_qubit_flux, 'Qubit {} SQUID flux'.format(qubit_name), 'Phi_0'),
#      30                                  (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
# ---> 31                                  filename=sample_name+' two-tone qubit{}'.format(qubit_name))
#      32     finally:
#      33         for coil_control_channel  in coil_control_channels:
#
# C:\qtlab_replacement\qsweepy\sweep.py in sweep(measurer, filename, root_dir, plot, plot_separate_thread, header, output, save, time_war_label, shuffle, bot, use_deferred, loc, *params)
#     179         if plot:
#     180                 plot_update_start = time.time()
# --> 181                 plot_axes = plotting.plot_measurement(mk_measurement(), name=filename)
#     182                 last_plot_update = time.time()
#     183                 plot_update_time = last_plot_update - plot_update_start
#
# C:\qtlab_replacement\qsweepy\plotting.py in plot_measurement(measurement, name, save, annotation, subplots)
#     216         else:
#     217                 plot_add_annotation(axes, annotation)
# --> 218         plt.figure(num=name).tight_layout(rect=[0.0, 0.03, 1, 0.95])
#     219         plot_save(axes, save)
#     220         # return all the axes, filters & plotting instructions for updates
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2365         kwargs = get_tight_layout_figure(
#    2366             self, self.axes, subplotspec_list, renderer,
# -> 2367             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2368         if kwargs:
#    2369             self.subplots_adjust(**kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     377         left, bottom, right, top = rect
#     378         if left is not None:
# --> 379             left += kwargs["left"]
#     380         if bottom is not None:
#     381             bottom += kwargs["bottom"]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
coil_device

# %%
pna.pre_sweep()
plt.plot(pna.get_freqpoints(),20*np.log10(np.abs(pna.measure()['Voltage'])))
pna.post_sweep()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-95f451915b26> in <module>()
#       1 pna.pre_sweep()
# ----> 2 plt.plot(pna.get_freqpoints(),20*np.log10(np.abs(pna.measure()['Voltage'])))
#       3 pna.post_sweep()
#
# KeyError: 'Voltage'

# %%
coil_device.set_current(-0.004)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# True

# %%
coil_device.get_current()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# 0.0

# %%
coil_device.set_status(0)
coil_device.set_current(0.00)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# True

# %% [markdown]
# ## Simple two-tone

# %%
if coil_device != current_src1:
    if coil_device ==awg_tek:
        raise ValueError('awg_tek is the active coil control device. This cell is for current_src1 (Yokogawa)')
    if coil_device ==dac:
        raise ValueError('dac is the active coil control device. This cell is for current_src1 (Yokogawa).')

        
#qubit_id='1'
current_max = 5.5e-3 # 7 mA - max on coil
#voltage_max = 1
current_nop = 111
currents=np.linspace(-current_max,current_max,current_nop)
#currents=np.linspace(-current_max,current_max,current_nop)
#current_src1.set_status(1)

lo1.set_status(0)
pna.set_power(-50) #-30

freq_nop =3981#161 #961
freq_nop =1001#161 #961
freqs= np.linspace(3.00e9,5e9,freq_nop)
#freqs= np.linspace(5e9,10e9,freq_nop)
pna.set_nop(1)
pna.set_bandwidth(10)
base_power = -10
frequency_gain  = 6.8
lo1.set_power(-10)
lo1.set_status(1)
delay = 70e-9

def sleep(x):
    coil_device.set_current(x)
for qubit_id in ['5']:#['1', '3']:
    
        coil_device.set_status(1)
        coil_device.set_current(0.00015)
        #coil_device.set_current(0)
        coil = 'DC_coil'
        res_freq = 7.492512e9#7.25414e9 #qubits[qubit_id]['r']['Fr']
        pna.set_frequency(res_freq)
        pna.set_centerfreq(res_freq)

                   
        def set_corrected_frequency(x):
            lo1.set_frequency(x)
            #lo1.set_power(x/1e9*frequency_gain+base_power)
            
        result = sweeper.sweep(pna,
                                 (freqs,set_corrected_frequency, 'Excitation frequency', 'Hz'),
                                 measurement_type='Simple_tone_tone_spectroscopy',
                                 metadata = {'resonator_id': qubit_id,
                                             'probe_power': pna.get_power(),
                                             'base_pump_power': lo1.get_power(),
                                             'frequeny_gain': frequency_gain,
                                             'bw': pna.get_bandwidth(),
                                             'fr': res_freq,
                                             'coil': coil,
                                             'coil_current':coil_device.get_current(),
                                            })
            
        coil_device.set_current(0)#0)
        coil_device.set_status(0)
        lo1.set_status(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# load time:  0.04398202896118164
# pre_trace_time:  0.0
# trace 0 time:  0.02098822593688965
# trace 1 time:  0.039990901947021484
# trace 2 time:  0.05796980857849121
# trace 3 time:  0.07596206665039062
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\memmap.py:335: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
coil_device.set_current(0)#0)
coil_device.set_status(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# True

# %%
voltage_max = 4
voltage_nop = 41
freq_nop = 401
nndac_channels = [2]
voltages=np.linspace(1,2.7,voltage_nop)
#voltages=np.linspace(-voltage_max,voltage_max,voltage_nop)
freqs= np.linspace(5e9,6.2e9,freq_nop)
pna.set_nop(1)
pna.set_bandwidth(50)
lo1.set_power(-0)
lo1.set_status(1)
delay = 55e-9
for nndac_channel_id in nndac_channels:
    for qubit_id in ['2']:
        pna.set_power(qubits[qubit_id]['r']['P'])
        try: 
            coil = 'NNDAC-'+str(nndac_channel_id)
            def set_volt_res(x):
                dac.set_voltage(x, channel=nndac_channel_id)
                res_freq = find_resonator(qubit_id, criterion='min_abs', delay=delay, check=1, raise_on_error=False)
                pna.set_frequency(res_freq)
                pna.set_centerfreq(res_freq)
            result = sweep.sweep(pna,
                                 (voltages, set_volt_res, 'Coil #{} voltage, qubit{}'.format(coil,qubit_id)),
                                 (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
                                 filename='Sample 809-001_2 Coil #{} two-tone qubit{}'.format(coil,qubit_id))
            dac.set_voltage(0,nndac_channel_id)
        except KeyboardInterrupt:
            for nndac_channel in nndac_channels:
                dac.set_voltage(0,nndac_channel)
            raise
        finally:
            for nndac_channel in nndac_channels:
                dac.set_voltage(0,nndac_channel)
# Out:
# A Jupyter Widget
# Started at:  Sep 19 2018 19:21:26
# resonator found at 6892100000.0
# resonator found at 6890600000.0
# resonator found at 6889300000.0
# resonator found at 6888000000.0
# resonator found at 6887000000.0
# resonator found at 6886300000.0
# resonator found at 6885500000.0
# resonator found at 6885100000.0
# resonator found at 6884600000.0
# resonator found at 6884000000.0
# resonator found at 6883500000.0
# resonator found at 6883100000.0
# resonator found at 6882900000.0
# resonator found at 6882500000.0
# resonator found at 6882300000.0
# resonator found at 6882200000.0
# resonator found at 6881800000.0
# resonator found at 6881800000.0
# resonator found at 6881700000.0
# resonator found at 6881400000.0
# resonator found at 6881600000.0
# resonator found at 6881200000.0
# resonator found at 6881200000.0
# resonator found at 6881100000.0
# resonator found at 6881100000.0
# resonator found at 6881200000.0
# resonator found at 6880900000.0
# resonator found at 6881000000.0
# resonator found at 6881400000.0
# resonator found at 6881300000.0
# resonator found at 6881100000.0
# resonator found at 6881500000.0
# resonator found at 6881700000.0
# resonator found at 6881700000.0
# resonator found at 6881600000.0
# resonator found at 6881900000.0
# resonator found at 6881900000.0
# resonator found at 6882300000.0
# resonator found at 6882700000.0
# resonator found at 6882800000.0
# resonator found at 6883100000.0
# Exiting sweep main thread #{} via return 12052
#
# Elapsed time: 0 h 22 m 19.41 s

# %% [markdown]
# ### power skan

# %%
qubits[qubit_id]['r']['P']
# Out:
# -65

# %%
qubits[qubit_id]['q']['P']
# Out:
# {'nndac_coil_id': 6,
#  'awg_tek_coil_channel': 1,
#  'coil_device_channel': 1,
#  'P': None,
#  'Fmin_coil_currents': {1: 0.4724919, 2: -0.60931336, 3: -0.59793759}}

# %%
pna.get_tracedata()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# (array([0.00063895]), array([-1.49693201]))

# %%
# voltage_max = 4
# voltage_nop = 41
# freq_nop = 401
nndac_channels = [2]
# powers=np.linspace(20,,voltage_nop)
# #voltages=np.linspace(-voltage_max,voltage_max,voltage_nop)
# freqs= np.linspace(5e9,6.2e9,freq_nop)
pna.set_nop(1)
pna.set_bandwidth(50)
# lo1.set_power(-0)
lo1.set_status(1)
delay = 55e-9





powers = np.arange(-20, 0, 1)
freqs = np.arange(4.0e9, 5.3e9, 2e6)


voltage_nop = 101
# fluxes=np.linspace(-0.75,0.25,voltage_nop)
pna.set_nop(1)
pna.set_bandwidth(20)
lo1.set_power(0)
pna.set_power(-30)
lo1.set_status(1)
delay = 70e-9
#for nndac_channel_id in nndac_channels:
for qubit_id, qubit_name in enumerate(['1']):#, '2', '3']):
    try: 
        for coil_control_channel  in coil_control_channels:
            coil_device.set_output(1, channel=coil_control_channel)
        def set_qubit_flux(x):
            fluxes = [0 ,0, 0]
            fluxes[qubit_id] = x
            voltages = np.linalg.solve(np.asarray(L_mat), -np.asarray(phi0_vec)+fluxes)
            for channel_id, channel_voltage in enumerate(voltages):
                coil_device.set_offset(voltages[channel_id], channel=coil_control_channels[channel_id])
            res_freq = find_resonator(qubit_name, criterion='max_dev_complex', delay=delay, check=1, raise_on_error=False)
            pna.set_frequency(res_freq)
            pna.set_centerfreq(res_freq)
        set_qubit_flux(-0.5)
        result = sweep.sweep(pna,
                                 (powers,lo1.set_power, '2 tone power at {}'.format(qubit_name), 'dB'),
                                 (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
                                 filename=sample_name+' two-tone qubit{}'.format(qubit_name))
    finally:
        for coil_control_channel  in coil_control_channels:
            coil_device.set_offset(0, channel=coil_control_channel)
            coil_device.set_output(0, channel=coil_control_channel)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# Could not find resonator
# HTML(value='')
# Started at:  Dec 01 2018 14:14:49
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning: ask is deprecated and will be removed in 1.10, use query instead.
#   '1.10, use query instead.', FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:176: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('Tight layout not applied. The left and right margins '
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-467e3753f5a8> in <module>()
#      46                                  (powers,lo1.set_power, '2 tone power at {}'.format(qubit_name), 'dB'),
#      47                                  (freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
# ---> 48                                  filename=sample_name+' two-tone qubit{}'.format(qubit_name))
#      49     finally:
#      50         for coil_control_channel  in coil_control_channels:
#
# C:\qtlab_replacement\qsweepy\sweep.py in sweep(measurer, filename, root_dir, plot, plot_separate_thread, header, output, save, time_war_label, shuffle, bot, use_deferred, loc, *params)
#     179         if plot:
#     180                 plot_update_start = time.time()
# --> 181                 plot_axes = plotting.plot_measurement(mk_measurement(), name=filename)
#     182                 last_plot_update = time.time()
#     183                 plot_update_time = last_plot_update - plot_update_start
#
# C:\qtlab_replacement\qsweepy\plotting.py in plot_measurement(measurement, name, save, annotation, subplots)
#     216         else:
#     217                 plot_add_annotation(axes, annotation)
# --> 218         plt.figure(num=name).tight_layout(rect=[0.0, 0.03, 1, 0.95])
#     219         plot_save(axes, save)
#     220         # return all the axes, filters & plotting instructions for updates
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2365         kwargs = get_tight_layout_figure(
#    2366             self, self.axes, subplotspec_list, renderer,
# -> 2367             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2368         if kwargs:
#    2369             self.subplots_adjust(**kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     377         left, bottom, right, top = rect
#     378         if left is not None:
# --> 379             left += kwargs["left"]
#     380         if bottom is not None:
#     381             bottom += kwargs["bottom"]
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ## Кубитная спектроскопия

# %% [markdown]
# # Импульсы

# %% [markdown]
# ### Загружаем импульсные скрипты всякие

# %%
import imp
from qsweepy import pulses as pulses
imp.reload(awg_digital)
imp.reload(awg_iq_multi)
imp.reload(data_reduce)
imp.reload(fitting)
imp.reload(plotting)
imp.reload(tomography)
imp.reload(sweep)
imp.reload(pulses)
imp.reload(awg_channel)
# Out:
# <module 'qsweepy.awg_channel' from 'C:\\qtlab_replacement\\qsweepy\\awg_channel.py'>

# %%
# Источник тока - в autorange
#current.set_autorange(1)
#Мощности гетеродинов, постоянные
#Мощность гетеродина для возбуждения 13-16 дБм

lo_ex_pow = 13
#lo_ex_pow = -20
lo_ex.set_status(1)
lo_ro_pow = 16
lo_ro.set_power(lo_ro_pow)

pna.write("OUTP ON")
pna.write("SOUR1:POW1:MODE ON")
pna.write("SOUR1:POW2:MODE OFF")
pna.set_sweep_mode("CW")
lo_ex.set_power(lo_ex_pow)

marker_length = 100
#readout_trigger_delay = 185
readout_trigger_delay = 0
trg_length = 10e-9

ex_clock = 1000e6
#ro_clock = 1250e6
ro_clock = 1000e6

rep_rate = 10e3 # частота повторений эксперимента
global_num_points = 100000-500

awg1.stop()
awg2.stop()
awg_tek.stop()

awg1.check_cached=True
awg2.check_cached=True
#awg_tek.set_clock(ex_clock) # клок всех авгшк
awg1.set_clock(ex_clock)
awg2.set_clock(ex_clock)
awg1.set_clock_output(True)
awg2.set_clock_output(True)
awg1.set_nop(ex_clock/rep_rate) # репрейт нужно задавать по=хорошему только на управляющей,
awg2.set_nop(ex_clock/rep_rate) # репрейт нужно задавать по=хорошему только на управляющей,
awg1.repetition_period = global_num_points
awg2.repetition_period = global_num_points

awg1.module.waveforms = [None]*4
awg1.module.AWGflush(nAWG=0) #убирает waveforms, которые были на этом канале
awg1.module.AWGflush(nAWG=1)
awg1.module.AWGflush(nAWG=2)
awg1.module.AWGflush(nAWG=3)
awg2.module.waveforms = [None]*4
awg2.module.AWGflush(nAWG=0)
awg2.module.AWGflush(nAWG=1)
awg2.module.AWGflush(nAWG=2)
awg2.module.AWGflush(nAWG=3)

# а вот длину сэмплов, которая очевидно то же самое, нужно задавать на всех авгшках.
# хорошо, что сейчас она только одна.
#this is zashkvar
awg2.set_trigger_mode(1) #external trigger mode
awg1.set_trigger_mode(1)

awg1.trigger_source_channels = [0, 0, 0, 0]
awg2.trigger_source_channels = [0, 0, 0, 0]#=0 for external trigger
#awg2.trigger_delays = [30+10,7+10,7+10,7+10]
awg1.trigger_delays = [1,1,1,1]
awg2.trigger_delays = [1,1,1,1]

awg1.trigger_behaviours = [4,4,4,4] #Trigger is active on the falling edge
awg2.trigger_behaviours = [4,4,4,4]

awg1.trigger_source_types = [6,6,6,6] # External HARDWARE trigger per cycle
awg2.trigger_source_types = [6,6,6,6]

for channel in range(0,4):
    #awg2.set_amplitude(0.4, channel=channel)
    awg2.set_offset(0.0,channel=channel)
    awg2.set_output(1, channel=channel)
    awg2.set_waveform(waveform = [0]*global_num_points, channel=channel)
for channel in range(0,4):
    #awg1.set_amplitude(1.0, channel=channel)
    awg1.set_offset(0.0,channel=channel)
    awg1.set_output(1, channel=channel)
    awg1.set_waveform(waveform =[0]*global_num_points, channel=channel)
    
awg1.set_amplitude(1.0, channel=0)
awg1.set_amplitude(1.0, channel=1)
awg1.set_amplitude(1.0, channel=2)
awg1.set_amplitude(1.0, channel=3)

awg2.set_amplitude(1.0, channel=0)
awg2.set_amplitude(1.0, channel=1)
awg2.set_amplitude(1.0, channel=2)
awg2.set_amplitude(1.0, channel=3)
    
print(awg1.module.clockResetPhase(3, 0))
print(awg2.module.clockResetPhase(3, 0))
    
awg2.set_marker(length=100, delay=0, channel=0, pxi_channels=1)
awg1.set_marker(length=200, delay=0, channel=0, pxi_channels=2)
awg2.run()
awg1.run()
awg_tek.run()

awg_channels =dict()


#adc.reset()
#Установить sample rate
#adc.set_clock(ro_clock)
#adc.set_clock_mode('pxi')

#Выбрать канал (оба)
#adc.select_channel01()
#adc.set_channel01_amps(200,200)

#adc.set_trigger_ext0_level0(500) # logical 0 value to 200 mV
#adc.set_trigger_ext0_level1(600) # logical 1 value to 600 mV
#adc.trigger_mode_pos()
#adc.set_trigger_ext0_pulsewidth(0)

#adc.set_trigger_ext0()
#adc.set_trigger_termination(1)
#Сегментированный режим
#adc.set_multi_mode()
#Настроить входнй диапазон в мв
#adc.init_channel01_multiple_recording()
#Настроить режим измерения
#adc.set_multi_record_mode()

#Выбрать канал (оба)
# Out:
# 0
# 0

# %%
awg_tek.stop()
awg_tek._visainstrument.write('AWGC:RMOD TRIG')
awg_tek._visainstrument.write('TRIG:WVAL LAST')
awg_tek._visainstrument.write('TRIG:IMP 1kohm')
awg_tek._visainstrument.write('TRIG:SLOP NEG')
awg_tek._visainstrument.write('TRIG:LEV 0.6')
awg_tek._visainstrument.write('SOUR1:ROSC:FREQ 10MHz')
awg_tek._visainstrument.write('SOUR1:ROSC:SOUR EXT')

#awg_tek.set_trigger_mode('CONT')
awg_tek.set_clock(1e9)
awg_tek.set_nop(ex_clock/rep_rate-500) # репрейт нужно задавать по=хорошему только на управляющей_t
awg_tek.check_cached = True

for channel in range(1,3):
    awg_tek.set_amplitude(1.0, channel=channel)
    awg_tek.set_offset(0.0,channel=channel)
    awg_tek.set_output(1, channel=channel)
    awg_tek.set_waveform([0]*global_num_points, channel=channel)
awg_tek.run()

awg_tek.set_digital([1]*90+[0]*(global_num_points+500-300), channel=1)
awg_tek.set_digital([1]*90+[0]*(global_num_points+500-300), channel=2)
for other_channels in [3,4,5,6,7,8]:
    awg_tek.set_digital([1]*1000+[0]*(global_num_points+500-1210), channel=other_channels)

awg_tek._visainstrument.write('SOUR1:DEL:ADJ 398 NS')
awg_tek._visainstrument.write('SOUR2:DEL:ADJ 398 NS')
awg_tek._visainstrument.write('SOUR3:DEL:ADJ 398 NS')
awg_tek._visainstrument.write('SOUR4:DEL:ADJ 398 NS')

#awg_tek._visainstrument.write('SOUR1:DEL:ADJ 398 NS')
#awg_tek._visainstrument.write('SOUR2:DEL:ADJ 398 NS')
#awg_tek._visainstrument.write('SOUR3:DEL:ADJ 398 NS')
#awg_tek._visainstrument.write('SOUR4:DEL:ADJ 398 NS')

awg_channels =dict()
ro_trg = awg_digital.awg_digital(awg_tek, 3)
ro_trg.mode = 'set_delay' #M3202A
ro_trg.delay_setter = lambda x: adc.set_trigger_delay(int(x*adc.get_clock()/iq_ex.get_clock()-readout_trigger_delay)) #M3202A
ro_trg.mode = 'waveform' #AWG5014C
awg_channels['ro_trg'] = ro_trg
# Out:
# WARNING:root:Tektronix_AWG5014 : Clock set to 1000000000.0. This is not fully functional yet. To avoid problems, it is better not to change the clock during operation
# root: WARNING  Tektronix_AWG5014 : Clock set to 1000000000.0. This is not fully functional yet. To avoid problems, it is better not to change the clock during operation
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %%
awg_tek.stop()
awg1.set_waveform([1]*200+[0]*(global_num_points-200), channel=0)
awg2.set_waveform([1]*200+[0]*(global_num_points-200), channel=0)

awg1.set_waveform([0]*200+[0]*(global_num_points-200), channel=0)
awg2.set_waveform([0]*200+[0]*(global_num_points-200), channel=0)
awg_tek.run()
awg1.run()
awg2.run()

# %%
imp.reload(awg_iq_multi)
imp.reload(modem_readout)
# Out:
# <module 'qsweepy.modem_readout' from 'C:\\qtlab_replacement\\qsweepy\\modem_readout.py'>

# %% [markdown]
# ### Калибровка миксеров

# %%
#qjson.invalidate_calibrations()

# %%
#ro_if = 75e6
lo_freq = 4.1e9#5.7 e9
lo_ro_freq = 7.6e9#6.75e9
    
imp.reload(awg_iq_multi)
# промежуточные частоты для гетеродинной схемы new:
lo1.set_frequency(lo_freq)
lo_ro.set_frequency(lo_ro_freq)
iq_ex1 = awg_iq_multi.awg_iq_multi(awg2, awg2, 0, 1, lo_ex) #M3202A
iq_ex2 = awg_iq_multi.awg_iq_multi(awg2, awg2, 2, 3, lo_ex) #M3202A
iq_ex3 = awg_iq_multi.awg_iq_multi(awg1, awg1, 2, 3, lo_ex) #M3202A
iq_ro = awg_iq_multi.awg_iq_multi(awg1, awg1, 0, 1, lo_ro) #M3202A
iq_ex1.name='ex1'
iq_ex2.name='ex2'
iq_ex3.name='ex3'

#iq_ex1.calibration_switch_setter = lambda: rf_switch.do_set_switch(1, channel=1) if not rf_switch.do_get_switch(channel=1)==1 else None
iq_ex2.calibration_switch_setter = lambda: rf_switch.do_set_switch(2, channel=1) if not rf_switch.do_get_switch(channel=1)==2 else None
#iq_ex2.calibration_switch_setter = lambda: rf_switch.do_set_switch(2, channel=1) if not rf_switch.do_get_switch(channel=1)==2 else None
#iq_ex3.calibration_switch_setter = lambda: rf_switch.do_set_switch(3, channel=1) if not rf_switch.do_get_switch(channel=1)==3 else None
iq_ro.calibration_switch_setter = lambda: rf_switch.do_set_switch(4, channel=1) if not rf_switch.do_get_switch(channel=1)==4 else None
#iq_ex = awg_iq_multi.awg_iq_multi(awg_tek, awg_tek, 1, 2, lo_ex) #M3202A

#iq_ro = awg_iq_multi.awg_iq_multi(awg_tek, awg_tek, 4, 3, lo_ro) #AWG5014C
readout_channels = {}
for _qubit_id in ['2']:#qubits.items():
    for tr,freq in qubits[_qubit_id]['q']['F'].items():
        iq_ro.carriers['iq_ro_q{}'.format(_qubit_id)] = awg_iq_multi.carrier(iq_ro)
        iq_ro.carriers['iq_ro_q{}'.format(_qubit_id)].set_frequency(qubits[_qubit_id]['r']['Fr'])
        awg_channels['iq_ro_q{}'.format(_qubit_id)] = iq_ro.carriers['iq_ro_q{}'.format(_qubit_id)]
        readout_channels['iq_ro_q{}'.format(_qubit_id)] = awg_channels['iq_ro_q{}'.format(_qubit_id)]
        for coil_id, iq_ex in [(2, iq_ex2)]:#, iq_ex2, iq_ex3]): #[]:#
            print(coil_id, iq_ex, tr, freq, _qubit_id)
            iq_ex.carriers['iq_ex{}_q{}_'.format(coil_id, _qubit_id)+tr] = awg_iq_multi.carrier(iq_ex)
            iq_ex.carriers['iq_ex{}_q{}_'.format(coil_id, _qubit_id)+tr].set_frequency(freq)
            awg_channels['iq_ex{}_q{}_'.format(coil_id, _qubit_id)+tr]=iq_ex.carriers['iq_ex{}_q{}_'.format(coil_id, _qubit_id)+tr]

#govno_channel = awg_digital.awg_digital(awg_tek, 5)
#govno_channel.get_frequency = lo1.get_frequency
#govno_channel.mode='waveform'
#awg_channels['govno_channel'] = govno_channel
#awg_tek.set_marker2_high(2.5, channel=1)
#awg_tek.set_marker2_low(0.0, channel=1)
#awg_tek.invert_marker[4] = True
            
for dc_coil_id in [1,2,3]:
    awg_channels['dc_coil{}'.format(dc_coil_id)] = awg_channel.awg_channel(awg_tek, dc_coil_id)
            
pg = pulses.pulses(awg_channels)
#print(ex_if*1e-6 ,lo_freq)

print("Excitation channel", end='\n')
iq_ex2.do_calibration(sa)
#iq_ex2.do_calibration(sa)
#iq_ex3.do_calibration(sa)
print("Readout channel", end='\n')
iq_ro.do_calibration(sa)
# Out:
# 2 <qsweepy.awg_iq_multi.awg_iq_multi object at 0x000001D29D7E6D30> F01_min 3788000000.0 2
# c:\data/calibrations/iq-rf/ cname-default-frequency-7.41e+09-if--1.9e+08-sideband_id-     0

# %%
awg_channels
# Out:
# {'ro_trg': <qsweepy.awg_digital.awg_digital at 0x1f81b3ddc88>,
#  'iq_ro_q2': <qsweepy.awg_iq_multi.carrier at 0x1f828ccc668>,
#  'govno_channel': <qsweepy.awg_digital.awg_digital at 0x1f824eb1b70>,
#  'dc_coil1': <qsweepy.awg_channel.awg_channel at 0x1f8250050b8>,
#  'dc_coil2': <qsweepy.awg_channel.awg_channel at 0x1f81b3e5b70>,
#  'dc_coil3': <qsweepy.awg_channel.awg_channel at 0x1f81b3e5898>}

# %% [markdown]
# ## задержка считывания

# %%
trigger_readout_seq = [pg.p('ro_trg', 20e-9, pg.rect, 1)]


adc.set_nums(50)
adc.set_nop(65536)
#adc.set_posttrigger(adc.get_nop()-4096)
if hasattr(adc, 'set_posttrigger'):
    adc.set_posttrigger(adc.get_nop()-32)
modem = modem_readout.modem_readout(pg, adc, trigger_readout_seq, axis_mean=0)
modem.readout_channels = readout_channels
#ro_trg.delay_setter = lambda x: adc.set_trigger_delay(int(x*adc.get_clock()/iq_ex.get_clock()-0)) # M3201A & M3202A
ro_trg.delay = 0#Spectrum+AWG5014C
delay_calibration = modem.calibrate_delay()

readout_trigger_delay = delay_calibration[awg_channels['iq_ro_q2']]
#readout_trigger_delay_cycles = readout_trigger_delay*adc.get_clock() M3201A
readout_trigger_delay_cycles = readout_trigger_delay*ro_trg.get_clock()
print (readout_trigger_delay, readout_trigger_delay_cycles)
ro_trg.delay_setter = lambda x: adc.set_trigger_delay(int(x*adc.get_clock()/iq_ex.get_clock())-readout_trigger_delay*adc.get_clock()) #M3201A
ro_trg.delay = int(-readout_trigger_delay_cycles-10)#Spectrum+AWG5014C
readout_trigger_delay_test = modem.calibrate_delay()[awg_channels['iq_ro_q2']]
## #readout_trigger_delay_cycles_test = readout_trigger_delay_test*adc.get_clock() M3201A
readout_trigger_delay_cycles_test = readout_trigger_delay_test*ro_trg.get_clock()
print (readout_trigger_delay_test, readout_trigger_delay_cycles_test)

modem_calibration_result = modem.calibrate_dc(amplitude=0.5)
# Out:
# -7.13e-07 -713.0
# -9e-09 -9.0
# (49750, 2) (49750,)

# %%
awg_tek.set_offset(0.4, channel=4)
awg_tek.set_output(1,channel=4)
# Out:
# True

# %% [markdown]
# ### Оно лечит если не работает

# %%
#adc_device.system_reset()
#adc_device.sync_req()

# %%
### TSW internal demodulation
demod_q2 = modem_calibration_result['iq_ro_q2']['feature'][:2048]/np.max(np.abs(modem_calibration_result['iq_ro_q2']['feature']))
#demod_q3 = modem_calibration_result['iq_ro_q3']['feature'][:2048]/np.max(np.abs(modem_calibration_result['iq_ro_q3']['feature']))
#3demod_q3 = calibration_result['iq_ro_q2']['feature'][:2048]/np.max(np.abs(calibration_result['iq_ro_q2']['feature']))
demod_q2 = np.asarray(2**15*demod_q2, dtype=complex)
#demod_q3 = np.asarray(2**15*demod_q3, dtype=complex)
demod_q2_real_int = np.asarray(np.real(demod_q2), dtype=np.int16)
demod_q2_imag_int = np.asarray(np.imag(demod_q2), dtype=np.int16)
#demod_q3_real_int = np.asarray(np.real(demod_q3), dtype=np.int16)
#demod_q3_imag_int = np.asarray(np.imag(demod_q3), dtype=np.int16)
adc_device.set_ram_data([demod_q2_real_int.tolist(),    (demod_q2_imag_int).tolist()], 0)
adc_device.set_ram_data([(demod_q2_imag_int).tolist(),  (-demod_q2_real_int).tolist()], 1)
#adc_device.set_ram_data([demod_q3_real_int.tolist(),    (demod_q3_imag_int).tolist()],  2)
#adc_device.set_ram_data([(demod_q3_imag_int).tolist(),  (-demod_q3_real_int).tolist()], 3)

# %% [markdown]
# ## усреднённое считывание

# %%
modem.filters = modem.calibrated_filters
adc_reducer = data_reduce.data_reduce(modem)
adc_reducer.filters = {'S21_r{}'.format(_qubit_id): 
            data_reduce.mean_reducer(modem, 'iq_ro_q{}'.format(_qubit_id), axis=0) for _qubit_id in qubits.keys()}
adc_reducer.extra_opts['scatter'] = True
adc_reducer.extra_opts['realimag'] = True

# %%
###TSWWWWW!!~!!
adc_reducer = TSW14J56_evm_reducer(adc_device)
adc_reducer.output_raw = False
adc_reducer.last_cov = False
adc_reducer.avg_cov = True
adc_reducer.resultnumber = False

# %%
adc_reducers = {_qubit_id:data_reduce.data_reduce(modem) for  _qubit_id in qubits.keys()}
for _qubit_id in qubits.keys():
    adc_reducers[_qubit_id].filters = {'S21_r{}'.format(_qubit_id):data_reduce.mean_reducer(
        modem, 'iq_ro_q{}'.format(_qubit_id), axis=0)}
    adc_reducers[_qubit_id].extra_opts['scatter'] = True
    adc_reducers[_qubit_id].extra_opts['realimag'] = True
        
adc_reducer.filters = {'S21_r{}'.format(_qubit_id): 
            data_reduce.mean_reducer(modem, 'iq_ro_q{}'.format(_qubit_id), axis=0) for _qubit_id in qubits.keys()}
#adc_reducer.extra_opts['scatter'] = True
#adc_reducer.extra_opts['realimag'] = True

# %% [markdown]
# ## длительность считывания

# %%
def set_adc_nop(ro_adc_length):
    #adc.stop() # Spectrum
    signal_size = int(np.ceil(4./3.*(ro_adc_length)*adc.get_clock()))
    nop = int( 2**np.ceil(np.log2(signal_size)) )
    #print (nop)
    adc.set_nop(nop)
    #adc.set_post_trigger(adc.get_nop()-64)
    
# "Измеритель средних прошедших импульсов"
# Просто усредняет всё по номеру сэмпла.
    
    
#ro_adc_length = 0.15e-6        # Вот такой длины считываем (опухоль Фёдорова!!)
#ro_amplitude =0.16
#ro_dac_length = 0.08e-6
ro_adc_length = 1.2e-6 #0.6e-6#1.2e-6
ro_dac_length = 0.3e-6#0.3e-6
#adc.set_nums(1000)
#adc.set_software_nums_multi(1)
#adc.set_nums(100)
set_adc_nop(ro_adc_length)
adc.set_nums(10000) #50000
#adc.set_nop(32768)
#adc.set_post_trigger(32576-64)

# %% [markdown]
# ## Прохождение считывающих испульсов разной амплитуды

# %%
imp.reload(sweep)
# Out:
# <module 'qsweepy.sweep' from 'C:\\qtlab_replacement\\qsweepy\\sweep.py'>

# %%
#%%mprun -f sweep.sweep
imp.reload(sweep)
imp.reload(plotting)
for _qubit_id in ['2']:
    #for coil_channel_id, channel_voltage in qubits[_qubit_id]['q']['P']['Fmin_coil_currents'].items():
    #    dac.set_voltage(channel_voltage, channel=nndac_channel_id)
    #    coil_device.set_offset(channel_voltage, channel=coil_channel_id)
    mean_sample = data_reduce.data_reduce(adc)
    #print (dir(mean_sample))
    #del mean_sample.measure_deferred_result
    mean_sample.filters['Mean_Voltage_AC'] = data_reduce.mean_reducer_noavg(adc, 'Voltage', 0)

    mean_sample.filters['S21p'] = data_reduce.mean_reducer_freq(adc, 'Voltage', 0, iq_ro.carriers['iq_ro_q{}'.format(_qubit_id)].get_if())
    mean_sample.filters['S21m'] = data_reduce.mean_reducer_freq(adc, 'Voltage', 0, -iq_ro.carriers['iq_ro_q{}'.format(_qubit_id)].get_if())
    # # Этот измеритель мы как правило используем когда точек не слишком много и все результаты его жизнедеятельности как правило 
    # # выглядят как ломаные. Чтобы было красиво, давайте лучше сделаем точки (а кривые потом получим фитованые)
    mean_sample.extra_opts['scatter'] = True

    #awg.check_cached = True

    mean_sample.filters['Std_Voltage_AC'] = data_reduce.std_reducer_noavg(adc, 'Voltage', 0, 1)
    def set_pulse_amplitude(x):
        #awg_tek.set_nop(awg_tek.get_clock()/rep_rate)
        pg.set_seq(trigger_readout_seq+[pg.p('iq_ro_q{}'.format(_qubit_id), ro_dac_length, pg.rect, x)])
        #awg_tek.run()
    measurement = sweeper.sweep(mean_sample, 
                                (np.linspace(0.0, 1., 21), set_pulse_amplitude, 'dac amp'), 
                                measurement_type='readout_passthrough',
                                metadata={'qubit_id':_qubit_id})
    del mean_sample.filters['Std_Voltage_AC']
# Out:
# {}
# C:\qtlab_replacement\qsweepy\instrument_drivers\Tektronix_AWG5014.py:651: ComplexWarning:
#
# Casting complex values to real discards the imaginary part
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
#
# C:\qtlab_replacement\qsweepy\instrument_drivers\Tektronix_AWG5014.py:616: ComplexWarning:
#
# Casting complex values to real discards the imaginary part
# Waiting to join deferred threads:
# <bound method database.update_in_database of <qsweepy.database.database object at 0x0000027722A56908>> start: 2019-04-25 08:59:09.213506, started/done/total sweeps: 0/21/21,
# Measured data:
# 'Mean_Voltage_AC': parameters: dac amp (),:[0.0, 1.0] (21 points) with setter
# Time (s),:[0.0, 2.047e-06] (2048 points) without setter
# data: [[ 1.96956445 +3.00870039j  0.77816445 +0.83600039j
#    0.40466445 -3.92989961j ...  1.27496445 +0.16790039j
#    3.02396445 +3.55950039j  1.11996445 +1.46100039j]
#  [ 0.73514873 -5.76711729j -6.22805127 +0.04678271j
#    2.56514873 +0.59948271j ...  3.08914873 +4.57418271j
#    5.30614873 -8.43161729j -6.46265127 +0.37118271j]
#  [-2.4616876  +3.00651826j -7.2869876  +6.05661826j
#   -5.2842876  +1.44881826j ...  0.2625124  -2.01318174j
#    0.1589124  +4.63251826j -5.4803876  +3.54941826j]
#  ...
#  [-0.33747983 -3.8717396j   4.61522017 -2.6055396j
#  -0.8960495 -0.79656042j -0.82109945-0.86190084j -0.90839491-1.03499952j
#  -0.93544437-1.06032569j -0.78413623-1.00344846j -0.72026836-0.92579426j]
# 'Std_Voltage_AC': parameters: dac amp (),:[0.0, 1.0] (21 points) with setter
# Time (s),:[0.0, 2.047e-06] (2048 points) without setter
# data: [[590.6656785 +0.j 594.38702658+0.j 602.19189183+0.j ... 594.74121861+0.j
#   593.68456999+0.j 590.75082685+0.j]
#  [597.52137189+0.j 592.235882  +0.j 589.11679774+0.j ... 592.69277962+0.j
#   594.01230339+0.j 593.70971822+0.j]
#  [587.96395448+0.j 591.3840342 +0.j 591.94156635+0.j ... 595.61762776+0.j
#   593.21509399+0.j 599.03918685+0.j]
#  ...
#  [594.45766691+0.j 591.84914852+0.j 594.78953542+0.j ... 596.22134413+0.j
#   599.64633265+0.j 590.40660727+0.j]
#  [593.66132018+0.j 597.10103677+0.j 592.8361954 +0.j ... 593.00545723+0.j
#   591.99337713+0.j 592.24119083+0.j]
#  [586.72619503+0.j 597.08237879+0.j 595.8488997 +0.j ... 598.99714755+0.j
#   597.02842629+0.j 586.96803576+0.j]] (<qsweepy.database.database object at 0x0000027722A56908>,)
# load_exdir: file open time:  0.0
# load_exdir: file open time:  0.0
# load_exdir: file open time:  0.0
# load time:  0.1200098991394043
# pre_trace_time:  0.009977579116821289
# trace 0 time:  0.01999831199645996
# trace 1 time:  0.04001355171203613
# trace 2 time:  0.060011863708496094
# trace 3 time:  0.08000993728637695
# trace 4 time:  0.09000968933105469
# trace 5 time:  0.1000070571899414
# trace 6 time:  0.11000609397888184
# trace 7 time:  0.11998939514160156
# trace 8 time:  0.1300041675567627
# trace 9 time:  0.13998770713806152
# trace 10 time:  0.14998602867126465
# trace 11 time:  0.15998530387878418
# trace 12 time:  0.18000078201293945
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\memmap.py:335: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# trace 13 time:  0.19999933242797852
# trace 14 time:  0.2299959659576416
# trace 15 time:  0.24999308586120605

# %%
zero_response = measurement['Mean_Voltage_AC'][2][0,:]
drive_amplitudes = measurement['Mean_Voltage_AC'][1][0][1:]
signal = measurement['Mean_Voltage_AC'][2][1:,:]
noise = measurement['Std_Voltage_AC'][2][1:,:]
error = noise/np.sqrt(adc.get_nums())
signal_overlap = np.sum(np.conj(signal[0,:])*signal[1:,:], axis=1)/drive_amplitudes[1:]
signal_overlap_estimate = np.real(signal_overlap[0])
signal_overlap_error = 0.5*np.sqrt(np.sum((np.abs(signal[1:,:])*error[0,:])**2, axis=1)+np.sum((np.abs(signal[0,:])*error[1:,:])**2,axis=1))/drive_amplitudes[1:]
#signal_overlap_estimate = (np.sum(np.abs(signal[0,:])**2) - np.sum(error[0,:]*np.abs(signal[0,:]))-np.sum(np.abs(error[0,:])**2))/drive_amplitudes[0]
#plt.figure()
#plt.plot(np.real(signal_overlap))
#plt.plot(np.sum(noise**2, axis=1)/adc.get_nums())
#plt.plot(signal_overlap_error)
compression = 10*np.log10(np.real(signal_overlap)/np.real(signal_overlap_estimate))
db_compression_point = np.argmax(10*np.log10(np.real(signal_overlap)/np.real(signal_overlap_estimate))<-1+10*np.log10(1-signal_overlap_error/signal_overlap_estimate))
#10*np.log10(np.real(signal_overlap)/np.real(signal_overlap_estimate)),-1+10*np.log10(1-signal_overlap_error/signal_overlap_estimate)
#10*np.log10(np.real(signal_overlap)/np.real(signal_overlap_estimate))<-1+10*np.log10(1-signal_overlap_error/signal_overlap_estimate)
if np.any(db_compression_point):
    ro_amplitude = drive_amplitudes[db_compression_point+1]
else:
    ro_amplitude = drive_amplitudes[-1]
print("Readout amplitude:",ro_amplitude)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-333-af57bb32b87a> in <module>()
# ----> 1 zero_response = measurement['Mean_Voltage_AC'][2][0,:]
#       2 drive_amplitudes = measurement['Mean_Voltage_AC'][1][0][1:]
#       3 signal = measurement['Mean_Voltage_AC'][2][1:,:]
#       4 noise = measurement['Std_Voltage_AC'][2][1:,:]
#       5 error = noise/np.sqrt(adc.get_nums())
#
# TypeError: 'measurement_state' object is not subscriptable

# %%
ro_amplitude = 0.6

# %%
plt.figure('Компрессия считывающего импульса')
plt.plot(drive_amplitudes[1:], compression)
plt.xlabel('Амплитуда считывания')
plt.ylabel('Компрессия, дБ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-a988becd0aa2> in <module>()
#       1 plt.figure('Компрессия считывающего импульса')
# ----> 2 plt.plot(drive_amplitudes[1:], compression)
#       3 plt.xlabel('Амплитуда считывания')
#       4 plt.ylabel('Компрессия, дБ')
#
# NameError: name 'drive_amplitudes' is not defined

# %%
ro_parameters = {"adc_len":ro_adc_length,'dac_len': ro_dac_length,'amp': ro_amplitude,'adc nums':adc.get_nums(),
                'trg_length':trg_length}
qjson.dump("setups","readout",ro_parameters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-586b7025116a> in <module>()
# ----> 1 ro_parameters = {"adc_len":ro_adc_length,'dac_len': ro_dac_length,'amp': ro_amplitude,'adc nums':adc.get_nums(),
#       2                 'trg_length':trg_length}
#       3 qjson.dump("setups","readout",ro_parameters)
#
# NameError: name 'ro_amplitude' is not defined

# %%
ro_amplitude = 0.35
#ro_sequence = trigger_readout_seq+[pg.p('iq_ro', ro_dac_length, pg.rect, ro_amplitude)]

# %%
readout_pulse = [ pg.pmulti(ro_dac_length, 
                            ('iq_ro_q2', pg.rect, 0.35))] 
                            #('iq_ro_q2', pg.rect, 0.5), 
                            #('iq_ro_q3', pg.rect, 0.1)) ]

# %% [markdown]
# # Раби+Рамзи

# %%
#working_point = [0.494, 0.30, -0.525]
#working_point = [0.504, 0, -0.440]
#working_point = [0.504,0.125,-0.502]
#coil_voltages = np.dot(np.linalg.inv(L_mat), -np.asarray(phi0_vec)+working_point)
#for coil_id, coil_voltage in enumerate(coil_voltages):
 #   coil_device.set_voltage(coil_voltage, channel=coil_control_channels[coil_id])

# %%
import qsweepy.qjson as pqjson
#import qsweepy.quantum_two_level_dynamics as dyn
imp.reload(qjson)
imp.reload(data_reduce)
imp.reload(plotting)
imp.reload(fitting)
imp.reload(sweep)
imp.reload(diff_readout)
# Out:
# <module 'qsweepy.diff_readout' from 'C:\\qtlab_replacement\\qsweepy\\diff_readout.py'>

# %%
Rabi_lengths = np.arange(0,50e-9, 1e-9)
Rabi_lengths_long = np.arange(0, 1500e-9, 20e-9)
delaysT2 = np.arange(0, 5000e-9, 10e-9)
delaysT2_coherence = np.arange(0, 10000e-9, 10e-9)
target_freq_offset = -4e6
target_freq_offset_coherence = -10e6
delaysT1 = np.arange(0, 15e-6,0.1e-6)
amplitudes = np.arange(0.0, 1.0, 0.01)
Rabi_amplitude_length = 100e-9
Rabi_freq_limiter = 50e6

# %%
#diff_adc_reducer = diff_readout.diff_readout(adc_reducer)

# %%
import qsweepy.two_level as dyn

# %%
imp.reload(two_level)
calibrated_qubits = ['2']
rf_coils = ['2']
main_rf_coils = {'2':2}

qubit_coil_tld = {}
qubit_coil_tld_weak = {}
fitters = {}
import qsweepy.two_level as dyn
for q_id in calibrated_qubits:
    qubit_coil_tld[q_id] = {}
    qubit_coil_tld_weak[q_id] = {}
    ro_meas_name = 'avg_cov{}'.format(int(q_id))
    fitters[q_id] = lambda x,y,ro_meas_name=ro_meas_name: fitting.fit1d(x,y,ro_meas_name)
    for rf_coil in rf_coils:
        qubit_coil_tld[q_id][rf_coil] = dyn.quantum_two_level_dynamics(pg,
                                               adc_reducer, #adc_reducers_chan[ex_channel],
                                               ex_channel='iq_ex{}_q{}_F01_min'.format(rf_coil, q_id),
                                               ro_channel='iq_ro_q{}'.format(q_id),
                                               ro_sequence=(trigger_readout_seq+readout_pulse),
                                               ex_amplitude=1.0,
                                               fitter=fitters[q_id], 
                                               shuffle=False,
                                               readout_measurement_name=ro_meas_name,      
                                               qubit_id=q_id,
                                               sample_name=sample_name,
                                               db = db)#sweeper=sweeper)
#        qubit_coil_tld[q_id][rf_coil] = dyn.quantum_two_level_dynamics(pg,
#                                               adc_reducer, #adc_reducers_chan[ex_channel],
#                                               ex_channel='govno_channel'.format(rf_coil, q_id),
#                                               ro_channel='iq_ro_q{}'.format(q_id),
#                                               ro_sequence=(trigger_readout_seq+readout_pulse),
#                                               ex_amplitude=1,
#                                               fitter=fitters[q_id], 
#                                               shuffle=False,
#                                               readout_measurement_name=ro_meas_name,
#                                               qubit_id=q_id,
#                                               sample_name=sample_name,
#                                               db = db)#sweeper=sweeper)
        try:
            qubit_coil_tld[q_id][rf_coil].load_calibration()
        except:
            pass
        try:
            qubit_coil_tld_weak[q_id][rf_coil].load_calibration()
        except:
            pass
# Out:
# c:\data/calibrations/setups/ readout
# Failed loading readout calibration: expected str, bytes or os.PathLike object, not NoneType
# c:\data/calibrations/two-level-rabi-rect/ c-iq_ex2_q2_F01_min-f-3.788e+09-amp-r1-i0
# Failed loading rabi frequency calibration: max() arg is an empty sequence

# %% [markdown]
# ## Rabi + Ramsey for RF coupling matrix

# %%
imp.reload(plotly_plot)
imp.reload(two_level)
# Out:
# <module 'qsweepy.two_level' from 'C:\\qtlab_replacement\\qsweepy\\two_level.py'>

# %%
#iq_ro = awg_channels['iq_ro_q2']
#awg_channels['iq_ex2_q2_F01_min'].set_waveform([1]*99500)

# %%
govno_channel.set_waveform([1]*99500)
#iq_ro.parent._set_dc(0.0)
lo1
