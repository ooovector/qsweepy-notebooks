# %%
#Locale settings
import locale
# Set to German locale to get comma decimal separater
locale.setlocale(locale.LC_NUMERIC, "deu_DEU")

from numpy import *
from matplotlib.pyplot import *
rcdefaults()

# Tell matplotlib to use the locale we set above
rcParams['axes.formatter.use_locale'] = True

# %matplotlib qt
from qsweepy import *
from qsweepy.ponyfiles import *
from qsweepy.instruments import *
from qsweepy.save_pkl import save_pkl
from matplotlib import interactive
interactive(True)
from importlib import reload

sample_name = '1906-003-dodik'

# %%
db = database.MyDatabase()
sweeper = sweep_extras.Sweeper(db, sample_name=sample_name)
exdir_db_inst = exdir_db.Exdir_db(db=db, sample_name=sample_name)

# %%
qubits = {
          '1': {'r':{
                    'Fr': 5.7253e9, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 5.720e9,#6.575e9,
                    'Fr_max': 5.75e9,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':21,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '2': {'r':{
                    'Fr': 5.7556e9,#7.4095e9,#7.41e9, #7.413e9,# first sample # second sample 7.8816e9,#'Fr': 6.7335e9,
                    'Fr_min': 5.74e9,#7.395e9,#6.72e9,
                    'Fr_max': 5.77e9,#7.415e9,#down  8.32e9,#8.84e9,##6.788e9,#6.884e9,#6.92e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                    {'F01_min':3.788e9},#5.8e9#5.010e9 - up},#{'F01_min':5.519e9},#5.52025
                    'P':
                     {
                     'nndac_coil_id':10,#2,!!!!!!!!
                     'awg_tek_coil_channel':4,
                     'coil_device_channel':4,
                     'P':None, 
                     }
                }},
          '3': {'r':{
                    'Fr': 5.791e+09, # first sample # second sample 7.373e9,# second sample 7.376e9,#6.8791e9,
                    'Fr_min': 5.786e+09,#6.734e9,#6.879e9,#6.82e9,
                    'Fr_max': 5.796e+09,# down 6.850e9,#7.304e9, ##6.76e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                    {'F01_min': 4.83644e9 }, #4.1923e9# 4.17799e9 #4.467e9#4.464e9#4.203e9},#4.675e9},#4.484e9 -up},#{'F01_min':5.45525e9},#5.45678
                    'P':
                     {
                    'nndac_coil_id':3,#4,!!!!!!
                    'awg_tek_coil_channel':3,
                    'coil_device_channel':3,
                     'P':None, 
                     }
                }},
          '4': {'r':{
                    'Fr': 5.837e9, # first sample # second sample 7.373e9,# second sample 7.376e9,#6.8791e9,
                    'Fr_min': 5.827e+09,#6.734e9,#6.879e9,#6.82e9,
                    'Fr_max': 5.847e+09,# down 6.850e9,#7.304e9, ##6.76e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                    {'F01_min': 4.83644e9 }, #4.1923e9# 4.17799e9 #4.467e9#4.464e9#4.203e9},#4.675e9},#4.484e9 -up},#{'F01_min':5.45525e9},#5.45678
                    'P':
                     {
                    'nndac_coil_id':17,#4,
                    'awg_tek_coil_channel':3,
                    'coil_device_channel':3,
                     'P':None, 
                     }
                }},
          '5': {'r':{
                    'Fr': 5.869e+09, # first sample # second sample 7.373e9,# second sample 7.376e9,#6.8791e9,
                    'Fr_min': 5.860e+09,#6.734e9,#6.879e9,#6.82e9,
                    'Fr_max': 5.879e+09,# down 6.850e9,#7.304e9, ##6.76e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                    {'F01_min': 4.83644e9 }, #4.1923e9# 4.17799e9 #4.467e9#4.464e9#4.203e9},#4.675e9},#4.484e9 -up},#{'F01_min':5.45525e9},#5.45678
                    'P':
                     {
                    'nndac_coil_id':13,#4, !!!!!!!!
                    'awg_tek_coil_channel':3,
                    'coil_device_channel':3,
                     'P':None, 
                     }
                }},
          '6': {'r':{
                    'Fr': 5.947e+09, #8.528e9 first sample # second sample 7.373e9,# second sample 7.376e9,#6.8791e9,
                    'Fr_min': 5.942e+09,#6.734e9,#6.879e9,#6.82e9,
                    'Fr_max': 5.952e+09,# down 6.850e9,#7.304e9, ##6.76e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                    {'F01_min': 0.615e9 }, #4.1923e9# 4.17799e9 #4.467e9#4.464e9#4.203e9},#4.675e9},#4.484e9 -up},#{'F01_min':5.45525e9},#5.45678
                    'P':
                     {
                    'nndac_coil_id':23,#4,
                    'awg_tek_coil_channel':3,
                    'coil_device_channel':3,
                     'P':None, 
                     }
                }},
          '7': {'r':{
                    'Fr': 5.982e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 5.972e+09,#6.575e9,
                    'Fr_max': 5.990e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':18,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '8': {'r':{
                    'Fr': 6.015e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.010e+09,#6.575e9,
                    'Fr_max': 6.020e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':4,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '9': {'r':{
                    'Fr': 6.0653e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.058e+09,#6.575e9,
                    'Fr_max': 6.072e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':9,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '10': {'r':{
                    'Fr': 6.102e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.094e+09,#6.575e9,
                    'Fr_max': 6.107e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':22,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '11': {'r':{
                    'Fr': 6.137e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.134e+09,#6.575e9,
                    'Fr_max': 6.144e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':8,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '12': {'r':{
                    'Fr': 6.1850e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.176e+09,#6.575e9,
                    'Fr_max': 6.191e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':5,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }}, 
          '13': {'r':{
                    'Fr': 6.225e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.220e+09,#6.575e9,
                    'Fr_max': 6.230e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':19,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '14': {'r':{
                    'Fr': 6.260e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.250e+09,#6.575e9,
                    'Fr_max': 6.266e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':12,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '15': {'r':{
                    'Fr': 6.312e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.306e+09,#6.575e9,
                    'Fr_max': 6.318e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':1,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '16': {'r':{
                    'Fr': 6.353e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.349e+09,#6.575e9,
                    'Fr_max': 6.359e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':15,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '17': {'r':{
                    'Fr': 6.391e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.386e+09,#6.575e9,
                    'Fr_max': 6.396e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':16,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '18': {'r':{
                    'Fr': 6.446e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.441e+09,#6.575e9,
                    'Fr_max': 6.451e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':2,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '19': {'r':{
                    'Fr': 6.486e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.482e+09,#6.575e9,
                    'Fr_max': 6.491e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':11,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '20': {'r':{
                    'Fr': 6.5267e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.522e+09,#6.575e9,
                    'Fr_max': 6.532e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':20,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '21': {'r':{
                    'Fr': 6.5823e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.576e+09,#6.575e9,
                    'Fr_max': 6.588e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':6,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '22': {'r':{
                    'Fr': 6.6218e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.618e+09,#6.575e9,
                    'Fr_max': 6.628e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':12,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '23': {'r':{
                    'Fr': 6.630e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.626e+09,#6.575e9,
                    'Fr_max': 6.638e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':7,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
          '24': {'r':{
                    'Fr': 6.661e+09, # first sample # second sample 7.0848e9,# second sample 7.085e9,#6.59783e9,
                    'Fr_min': 6.657e+09,#6.575e9,
                    'Fr_max': 6.667e+09,#7.100e9# down 6.702e9,#7.110e9,##6.62e9,
                     'dFr': 0.1e6,#0.1e6, # tolerance of resonator frequency
                     'P': -45 },
                'q':{
                    "F":
                     {'F01_min': 4.16338e9}, # 4.17799e9#4.1173e9 #4.242e9#4.23819e9#4.159e9},#4.535e9}, #4.622e9 - up},#5.505e9}, # was 5.508e9,last 5.51812
                     'P':
                     {'nndac_coil_id':0,#0,
                      'awg_tek_coil_channel':4,
                      'coil_device_channel':4,
                     'P':None,    
                     }
                    }},
   
         }

# %%
flux_bias = nndac('TCPIP0::10.20.61.12::1000::SOCKET')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %%
pna = RS_ZNB20('pna', address = 'TCPIP0::10.20.61.161::inst0::INSTR')
lo1 = Agilent_E8257D('lo1', address = 'TCPIP0::10.20.61.10::inst0::INSTR')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %%
qubits['7']
# Out:
# {'r': {'Fr': 5982000000.0,
#   'Fr_min': 5972000000.0,
#   'Fr_max': 5990000000.0,
#   'dFr': 100000.0,
#   'P': -45},
#  'q': {'F': {'F01_min': 4163380000.0},
#   'P': {'nndac_coil_id': 18,
#    'awg_tek_coil_channel': 4,
#    'coil_device_channel': 4,
#    'P': None}}}

# %%
resonator_id = "3"
lo1.set_status(0)
pna.set_xlim(qubits[resonator_id]['r']['Fr_min'], qubits[resonator_id]['r']['Fr_max'])
pna.set_nop((qubits[resonator_id]['r']['Fr_max']-
                 qubits[resonator_id]['r']['Fr_min'])/qubits[resonator_id]['r']['dFr']+1)
pna.set_bandwidth(156)
pna.set_power(-55)
S21 = pna.measure()['S-parameter']
freqs = pna.get_points()['S-parameter'][0][1]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %%
plot(abs(S21))

# %%
resonator_id = "3"
powers = arange(-59,-20,1)
ref_power = -58
ref_bw = 20

lo1.set_status(0)
pna.set_xlim(qubits[resonator_id]['r']['Fr_min'], qubits[resonator_id]['r']['Fr_max'])
pna.set_nop((qubits[resonator_id]['r']['Fr_max']-
                 qubits[resonator_id]['r']['Fr_min'])/qubits[resonator_id]['r']['dFr']+1)

freqs = pna.get_points()['S-parameter'][0][1]
Fres = zeros(len(powers))

for i,power in enumerate(powers):
    pna.set_bandwidth( ref_bw*10**((power - ref_power)/10) )
    pna.set_power(power)
    S21 = pna.measure()['S-parameter']
    Fres[i] = freqs[argmin(abs(S21))]
    print(i, len(powers), end = '\r')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# 38 39

# %%
def ro_bw_optimizer(f_range, f_acc):
    state = 'searching'
    pna.set_xlim( f_range[0], f_range[1] )
    n = (f_range[1]-f_range[0])/f_acc
    #print (n)
    pna.set_nop( n)
    freqs = pna.get_points()['S-parameter'][0][1]
    f_res  = 1
    bw = 10000
    bw_min = 10
    n_meas = 100
    
    stable_count = 0
    minuma_found_thr = 2
    
    success = False
    while( bw>= bw_min ):
        #print(bw, state)
        pna.set_bandwidth( bw )
        S21 = pna.measure()['S-parameter']
        f_res = freqs[argmin(abs(S21))]
        #print(f_res)
        pna.set_xlim( f_res - f_acc,  f_res + f_acc )
        pna.set_nop(3)
        stable_count=0
        for i in range(n_meas):
            state ='stable'
            S21 = pna.measure()['S-parameter']
            #print( argmin(abs(S21)) )
            if argmin(abs(S21)) != 1:
                if (stable_count>minuma_found_thr):
                    state = 'minima_found'
                else:
                    state = 'searching'
                break
            else: stable_count+=1
                
        if(state == 'stable'): break
        elif (state == 'minima_found'):
            bw = bw/2
            pna.set_xlim( f_res - f_acc*2.,  f_res + f_acc*2. )
            pna.set_nop(5)
            freqs = pna.get_points()['S-parameter'][0][1]
        else:    
            bw = bw/2.
            pna.set_xlim( f_range[0], f_range[1] )
            pna.set_nop( n)
            freqs = pna.get_points()['S-parameter'][0][1]
        
    return bw

# %%
resonator_id = "3"
pna.set_power(-58)
ro_bw_optimizer( (qubits[resonator_id]['r']['Fr_min'], qubits[resonator_id]['r']['Fr_max'] ), 100e3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# 19.53125

# %%
plot(10**(powers/10), Fres )
show()

# %%
plot(powers, Fres )
show()

# %%
import pickle
f = open('C:\\Users\\cryopxi\\Documents\\Abramov\\polochka_-0.5v.pkl', 'wb')
pickle.dump( {'powers':powers, 'Fres': Fres,} ,f )
f.close()

# %%
resonator_id = "7"
pna.set_power(-40)
pna.set_bandwidth(20)
lo1.set_status(0)
pna.set_xlim(qubits[resonator_id]['r']['Fr_min'], qubits[resonator_id]['r']['Fr_max'])
pna.set_nop((qubits[resonator_id]['r']['Fr_max']-
                 qubits[resonator_id]['r']['Fr_min'])/qubits[resonator_id]['r']['dFr']+1)
freqs = pna.get_points()['S-parameter'][0][1]
S21 = pna.measure()['S-parameter']
f_ro = freqs[argmin(abs(S21))]
print(f_ro)
plot(freqs, abs(S21))
show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# 5985300000.0

# %% [markdown]
# ## Two tone spectroscopy

# %%
qubit_id='7'

ex_freqs = np.arange(3e9, 4.5e9, 2e6)
ex_power = 18

pna.set_bandwidth(2)
pna.set_power(-15)

pna.set_nop(1)

pna.set_frequency(f_ro)
pna.set_centerfreq(f_ro)
#def set_volt_res():
    #for _qubit_id in ['1']:
        #for coil_channel_id, channel_voltage in qubits[_qubit_id]['q']['P']['Fmin_coil_currents'].items():
            #dac.set_voltage(channel_voltage, channel=nndac_channel_id)
            #coil_device.set_offset(channel_voltage, channel=coil_channel_id)
    #res_freq = find_resonator(qubit_id, criterion='max_dev_complex', delay=delay,
                                  #check=3, raise_on_error=False)
    #print(res_freq)
#set_volt_res()

lo1.set_status(1)
lo1.set_power(ex_power)
result = sweeper.sweep(pna,
                     (ex_freqs,lo1.set_frequency, 'Excitation frequency', 'Hz'),
                     measurement_type='tone_tone',
                     metadata = {'resonator_id': qubit_id,})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:573: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# ...

# %%
def find_resonator(resonator_id, criterion='max_dev_complex', delay=0, check=1, raise_on_error=True): 
#    print ('resonator_id: ', resonator_id)
    # turn of all second tones
    lo1_status = lo1.get_status()
    lo1.set_status(0)
    # prior bandwidth
    bandwidth = pna.get_bandwidth()
    pna.set_bandwidth(100)
    average = pna.get_average()
    pna.set_average(0)
    #pna.set_power(-60)
    #pna.set_nop(501)
    nop = pna.get_nop()
    xlim = pna.get_xlim()
    pna.set_nop((qubits[resonator_id]['r']['Fr_max']-
                 qubits[resonator_id]['r']['Fr_min'])/qubits[resonator_id]['r']['dFr']+1)
    #pna.set_nop((30e6)/qubits[resonator_id]['r']['dFr']+1)
    pna.set_xlim(qubits[resonator_id]['r']['Fr_min'], qubits[resonator_id]['r']['Fr_max'])
    #pna.set_xlim(qubits[qubit_id]['r']['Fr_min']-10e6, qubits[qubit_id]['r']['Fr_max']+20e6)
    #current_src1.set_current(current)
    
    # measure S21
    results = []
    S21=[]
    for iteration_id in range(check+1):
        S21 = pna.measure()['S-parameter']
        freqs = pna.get_points()['S-parameter'][0][1]
    
        if (criterion == 'max_dev_complex'):
            measurement = S21*np.exp(2*np.pi*1j*freqs*delay)
            #plt.figure()
            #plt.plot(freqs, np.real(measurement-np.mean(measurement)))
            #plt.plot(freqs, np.imag(measurement-np.mean(measurement)))
            #plt.plot(freqs, np.abs(measurement-np.mean(measurement)))
            results.append(freqs[np.argmax(np.abs(measurement-np.mean(measurement)))])
        if (criterion == 'min_abs'):
            measurement = np.abs(S21)
            results.append(freqs[np.argmin(measurement)])
            
    # if resonator is off by more 3 times tolerance, raise if raise_on_error, otherwise warn
    if (np.std(results)>qubits[resonator_id]['r']['dFr']*10):
        if raise_on_error:
            raise Exception('Could not find resonator')
        else:
            print ('Could not find resonator')
    else: 
        print('resonator found at '+str(np.mean(results)))
        
    lo1.set_status(lo1_status)
    pna.set_bandwidth(bandwidth)
    pna.set_average(average)
    pna.set_nop(nop)
    pna.set_xlim(*xlim)
    
    return np.mean(results)
