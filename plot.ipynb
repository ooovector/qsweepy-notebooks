# %%
from numpy import *
import pickle as pkl
from matplotlib.pyplot import *

# %%
filename = "D:/Abramov/data/2018-06-22/20-32-31/S-parameter None.pkl"
f = open(filename, 'rb')
data = pkl.load(f)

# %%
x = data[1]['S-parameter'][1][0]
y = data[1]['S-parameter'][1][1]
z= data[1]['S-parameter'][2]

# %%
# %matplotlib
pcolormesh(x,y,abs(z).T)
show()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
-1.286+1.211
# Out:
# -0.07499999999999996

# %%
len(z)
# Out:
# 80

# %%
delay = diff(unwrap(angle(z)))
delay = hstack( (reshape(delay[::,0], (len(delay),1)), delay) )

pcolormesh(x,y,delay.T)
show()

# %%
reshape(delay[::,0], (len(delay),1))
# Out:
# array([[-0.06105545],
#        [-0.07339454],
#        [-0.07673164],
#        [-0.03060812],
#        [-0.01703057],
#        [-0.05539032],
#        [-0.06073372],
#        [-0.06170084],
#        [-0.0409465 ],
#        [-0.03667505],
#        [-0.04427812],
#        [-0.07486547],
#        [-0.03966978],
#        [-0.03069623],
#        [-0.03441316],
#        [-0.0315003 ],
#        [-0.03547642],
#        [-0.02441834],
#        [-0.02532584],
#        [-0.03469278],
#        [-0.06456141],
#        [-0.0687246 ],
#        [-0.07681026],
#        [-0.05314335],
#        [-0.05753207],
#        [-0.05931072],
#        [-0.04030797],
#        [-0.01834453],
#        [-0.05945433],
#        [-0.06413877],
#        [-0.06128132],
#        [-0.04922069],
#        [-0.04526665],
#        [-0.03087182],
#        [-0.04139815],
#        [-0.06063857],
#        [-0.0527042 ],
#        [-0.05469086],
#        [-0.08267193],
#        [-0.04174905],
#        [-0.00300611],
# ...
